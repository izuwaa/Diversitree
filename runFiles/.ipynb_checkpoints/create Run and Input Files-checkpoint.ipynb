# %% [markdown]
# #### RUN FILES

# %%
trainSet = ['air03','bell5','dcmulti','fiber','fixnet6','gen','gesa3','gt2','khb05250','l152lav','misc03','misc06','mod008','mod010','p0033','p0201','p0548','pp08a','pp08aCUTS','qnet1_o','qnet1','rgn','set1ch','stein27','stein45','vpm1','vpm2']

# %%
trainSet
# Out:
# ['air03',
#  'bell5',
#  'dcmulti',
#  'fiber',
#  'fixnet6',
#  'gen',
#  'gesa3',
#  'gt2',
#  'khb05250',
#  'l152lav',
#  'misc03',
#  'misc06',
#  'mod008',
#  'mod010',
#  'p0033',
#  'p0201',
#  'p0548',
#  'pp08a',
#  'pp08aCUTS',
#  'qnet1_o',
#  'qnet1',
#  'rgn',
#  'set1ch',
#  'stein27',
#  'stein45',
#  'vpm1',
#  'vpm2']

# %%
len(trainSet)
# Out:
# 27

# %%
# numNearOptimal = [10,50,100,200]
numNearOptimal = [1000]

# %%
percentages = ['1p','2p','3p','4p','5p','6p','7p','8p','9p','10p']

# %%
cwd = os.getcwd() + '/Train'
print(cwd)

for percent in percentages:
    
    for problem in trainSet:
        
        for j in numNearOptimal:
            
            fName = percent + str(j) + problem
            testFileName = percent + str(j) + problem + '.txt'
            fullFName = cwd  +'/' + fName
            
            print('writing ',fName, '\n')
            with open(fullFName,'w') as f:
                f.write('#!/bin/bash')
                f.write('\n')
                f.write('#')
                f.write('\n')
                f.write('#PBS -N ' + percent + fName)
                f.write('\n')
                f.write('#PBS -M iahanor@vols.utk.edu')
                f.write('\n')
                f.write('#PBS -m abe')
                f.write('\n')
                f.write('#PBS -A ACF-UTK0011')
                f.write('\n')
                f.write('#PBS -o /lustre/haven/user/iahanor/branchandbound/Train/' +  percent + '/' + fName + 'O.txt')
                f.write('\n')
                f.write('#PBS -e /lustre/haven/user/iahanor/branchandbound/Train/' + percent + '/' + fName + 'E.txt')
                f.write('\n')
                f.write('#PBS -l walltime=24:00:00')
                f.write('\n')
                f.write('#PBS -l nodes=1:ppn=4')
                f.write('\n')
                f.write('#PBS -l partition=gpu')
                f.write('\n')
                f.write('#PBS -l feature=cascadelake_gpu')
                f.write('\n')
                f.write('\n')
                f.write('cd /lustre/haven/user/iahanor/branchandbound/Train/' + percent)
                f.write('\n')
                f.write('mkdir ' + fName + 'F')
                f.write('\n')
                f.write('cd ' + fName + 'F')
                f.write('\n')
                f.write('\n')
                f.write('git clone https://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@github.com/izuwaa/Diversitree.git')
                f.write('\n')
                f.write('cd Diversitree')
                f.write('\n')
                f.write('module load gcc/6.3.0')
                f.write('\n')
                f.write('module load cmake')
                f.write('\n')
                f.write('\n')
                f.write('cmake -Bbuild -H. -DSCIP_DIR=/lustre/haven/user/iahanor/branchandbound/scipoptsuite-7.0.3/installDir/lib/cmake/scip -DGMP_INCLUDE_DIR=/sw/cs400_centos7.3_acfsoftware/gmp/5.1.1/centos7.3_intel17.2.174/include')
                f.write('\n')
                f.write('cmake --build build')
                f.write('\n')
                f.write('echo "module loaded"')
                f.write('\n')
                f.write('\n')
                f.write('cd /lustre/haven/user/iahanor/branchandbound/Train/' + percent + '/' + fName + 'F' + '/' + 'Diversitree')
                f.write('\n')
                f.write('/lustre/haven/user/iahanor/branchandbound/Train/' + percent + '/' + fName + 'F' + '/' + 'Diversitree/build/diversitree ' + testFileName + ' problemOptions , solverParams.txt solverOptions :')
                f.write('\n')
                f.write('echo "module I am done"')
# Out:
# writing  1p10air03
#
# writing  1p50air03
#
# writing  1p100air03
#
# writing  1p200air03
#
# writing  1p10bell5
#
# writing  1p50bell5
#
# writing  1p100bell5
#
# writing  1p200bell5
#
# writing  1p10dcmulti
#
# writing  1p50dcmulti
#
# writing  1p100dcmulti
#
# writing  1p200dcmulti
#
# writing  1p10fiber
#
# writing  1p50fiber
#
# writing  1p100fiber
#
# writing  1p200fiber
#
# writing  1p10fixnet6
#
# writing  1p50fixnet6
#
# writing  1p100fixnet6
#
# writing  1p200fixnet6
#
# writing  1p10gen
#
# writing  1p50gen
#
# writing  1p100gen
#
# writing  1p200gen
#
# writing  1p10gesa3
#
# writing  1p50gesa3
#
# writing  1p100gesa3
#
# writing  1p200gesa3
#
# writing  1p10gt2
#
# writing  1p50gt2
#
# writing  1p100gt2
#
# writing  1p200gt2
#
# writing  1p10khb05250
#
# writing  1p50khb05250
#
# writing  1p100khb05250
#
# writing  1p200khb05250
#
# writing  1p10l152lav
#
# writing  1p50l152lav
#
# writing  1p100l152lav
#
# writing  1p200l152lav
#
# writing  1p10misc03
#
# writing  1p50misc03
#
# writing  1p100misc03
#
# writing  1p200misc03
#
# writing  1p10misc06
#
# writing  1p50misc06
#
# writing  1p100misc06
#
# writing  1p200misc06
#
# writing  1p10mod008
#
# writing  1p50mod008
#
# writing  1p100mod008
#
# writing  1p200mod008
#
# writing  1p10mod010
#
# writing  1p50mod010
#
# writing  1p100mod010
#
# writing  1p200mod010
#
# writing  1p10p0033
#
# writing  1p50p0033
#
# writing  1p100p0033
#
# writing  1p200p0033
#
# writing  1p10p0201
#
# writing  1p50p0201
#
# writing  1p100p0201
#
# writing  1p200p0201
#
# writing  1p10p0548
#
# writing  1p50p0548
#
# writing  1p100p0548
#
# writing  1p200p0548
#
# writing  1p10pp08a
#
# writing  1p50pp08a
#
# writing  1p100pp08a
#
# writing  1p200pp08a
#
# writing  1p10pp08aCUTS
#
# writing  1p50pp08aCUTS
#
# writing  1p100pp08aCUTS
#
# writing  1p200pp08aCUTS
#
# writing  1p10qnet1_o
#
# writing  1p50qnet1_o
#
# writing  1p100qnet1_o
#
# writing  1p200qnet1_o
#
# writing  1p10qnet1
#
# writing  1p50qnet1
#
# writing  1p100qnet1
#
# writing  1p200qnet1
#
# writing  1p10rgn
#
# writing  1p50rgn
#
# writing  1p100rgn
#
# writing  1p200rgn
#
# writing  1p10set1ch
#
# writing  1p50set1ch
#
# writing  1p100set1ch
#
# writing  1p200set1ch
#
# writing  1p10stein27
#
# writing  1p50stein27
#
# writing  1p100stein27
#
# writing  1p200stein27
#
# writing  1p10stein45
#
# writing  1p50stein45
#
# writing  1p100stein45
#
# writing  1p200stein45
#
# writing  1p10vpm1
#
# writing  1p50vpm1
#
# writing  1p100vpm1
#
# writing  1p200vpm1
#
# writing  1p10vpm2
#
# writing  1p50vpm2
#
# writing  1p100vpm2
#
# writing  1p200vpm2
#
# writing  2p10air03
#
# writing  2p50air03
#
# writing  2p100air03
#
# writing  2p200air03
#
# writing  2p10bell5
#
# writing  2p50bell5
#
# writing  2p100bell5
#
# writing  2p200bell5
#
# writing  2p10dcmulti
#
# writing  2p50dcmulti
#
# writing  2p100dcmulti
#
# writing  2p200dcmulti
#
# writing  2p10fiber
#
# writing  2p50fiber
#
# writing  2p100fiber
#
# writing  2p200fiber
#
# writing  2p10fixnet6
#
# writing  2p50fixnet6
#
# writing  2p100fixnet6
#
# writing  2p200fixnet6
#
# writing  2p10gen
#
# writing  2p50gen
#
# writing  2p100gen
#
# writing  2p200gen
#
# writing  2p10gesa3
#
# writing  2p50gesa3
#
# writing  2p100gesa3
#
# writing  2p200gesa3
#
# writing  2p10gt2
#
# writing  2p50gt2
#
# writing  2p100gt2
#
# writing  2p200gt2
#
# writing  2p10khb05250
#
# writing  2p50khb05250
#
# writing  2p100khb05250
#
# writing  2p200khb05250
#
# writing  2p10l152lav
#
# writing  2p50l152lav
#
# writing  2p100l152lav
#
# writing  2p200l152lav
#
# writing  2p10misc03
#
# writing  2p50misc03
#
# writing  2p100misc03
#
# writing  2p200misc03
#
# writing  2p10misc06
#
# writing  2p50misc06
#
# writing  2p100misc06
#
# writing  2p200misc06
#
# writing  2p10mod008
#
# writing  2p50mod008
#
# writing  2p100mod008
#
# writing  2p200mod008
#
# writing  2p10mod010
#
# writing  2p50mod010
#
# writing  2p100mod010
#
# writing  2p200mod010
#
# writing  2p10p0033
#
# writing  2p50p0033
#
# writing  2p100p0033
#
# writing  2p200p0033
#
# writing  2p10p0201
#
# writing  2p50p0201
#
# writing  2p100p0201
#
# writing  2p200p0201
#
# writing  2p10p0548
#
# writing  2p50p0548
#
# writing  2p100p0548
#
# writing  2p200p0548
#
# writing  2p10pp08a
#
# writing  2p50pp08a
#
# writing  2p100pp08a
#
# writing  2p200pp08a
#
# writing  2p10pp08aCUTS
#
# writing  2p50pp08aCUTS
#
# writing  2p100pp08aCUTS
#
# writing  2p200pp08aCUTS
#
# writing  2p10qnet1_o
#
# writing  2p50qnet1_o
#
# writing  2p100qnet1_o
#
# writing  2p200qnet1_o
#
# writing  2p10qnet1
#
# writing  2p50qnet1
#
# writing  2p100qnet1
#
# writing  2p200qnet1
#
# writing  2p10rgn
#
# writing  2p50rgn
#
# writing  2p100rgn
#
# writing  2p200rgn
#
# writing  2p10set1ch
#
# writing  2p50set1ch
#
# writing  2p100set1ch
#
# writing  2p200set1ch
#
# writing  2p10stein27
#
# writing  2p50stein27
#
# writing  2p100stein27
#
# writing  2p200stein27
#
# writing  2p10stein45
#
# writing  2p50stein45
#
# writing  2p100stein45
#
# writing  2p200stein45
#
# writing  2p10vpm1
#
# writing  2p50vpm1
#
# writing  2p100vpm1
#
# writing  2p200vpm1
#
# writing  2p10vpm2
#
# writing  2p50vpm2
#
# writing  2p100vpm2
#
# writing  2p200vpm2
#
# writing  3p10air03
#
# writing  3p50air03
#
# writing  3p100air03
#
# writing  3p200air03
#
# writing  3p10bell5
#
# writing  3p50bell5
#
# writing  3p100bell5
#
# writing  3p200bell5
#
# writing  3p10dcmulti
#
# writing  3p50dcmulti
#
# writing  3p100dcmulti
#
# writing  3p200dcmulti
#
# writing  3p10fiber
#
# writing  3p50fiber
#
# writing  3p100fiber
#
# writing  3p200fiber
#
# writing  3p10fixnet6
#
# writing  3p50fixnet6
#
# writing  3p100fixnet6
#
# writing  3p200fixnet6
#
# writing  3p10gen
#
# writing  3p50gen
#
# writing  3p100gen
#
# writing  3p200gen
#
# writing  3p10gesa3
#
# writing  3p50gesa3
#
# writing  3p100gesa3
#
# writing  3p200gesa3
#
# writing  3p10gt2
#
# writing  3p50gt2
#
# writing  3p100gt2
#
# writing  3p200gt2
#
# writing  3p10khb05250
#
# writing  3p50khb05250
#
# writing  3p100khb05250
#
# writing  3p200khb05250
#
# writing  3p10l152lav
#
# writing  3p50l152lav
#
# writing  3p100l152lav
#
# writing  3p200l152lav
#
# writing  3p10misc03
#
# writing  3p50misc03
#
# writing  3p100misc03
#
# writing  3p200misc03
#
# writing  3p10misc06
#
# writing  3p50misc06
#
# writing  3p100misc06
#
# writing  3p200misc06
#
# writing  3p10mod008
#
# writing  3p50mod008
#
# writing  3p100mod008
#
# writing  3p200mod008
#
# writing  3p10mod010
#
# writing  3p50mod010
#
# writing  3p100mod010
#
# writing  3p200mod010
#
# writing  3p10p0033
#
# writing  3p50p0033
#
# writing  3p100p0033
#
# writing  3p200p0033
#
# writing  3p10p0201
#
# writing  3p50p0201
#
# writing  3p100p0201
#
# writing  3p200p0201
#
# writing  3p10p0548
#
# writing  3p50p0548
#
# writing  3p100p0548
#
# writing  3p200p0548
#
# writing  3p10pp08a
#
# writing  3p50pp08a
#
# writing  3p100pp08a
#
# writing  3p200pp08a
#
# writing  3p10pp08aCUTS
#
# writing  3p50pp08aCUTS
#
# writing  3p100pp08aCUTS
#
# writing  3p200pp08aCUTS
#
# writing  3p10qnet1_o
#
# writing  3p50qnet1_o
#
# writing  3p100qnet1_o
#
# writing  3p200qnet1_o
#
# writing  3p10qnet1
#
# writing  3p50qnet1
#
# writing  3p100qnet1
#
# writing  3p200qnet1
#
# writing  3p10rgn
#
# writing  3p50rgn
#
# writing  3p100rgn
#
# writing  3p200rgn
#
# writing  3p10set1ch
#
# writing  3p50set1ch
#
# writing  3p100set1ch
#
# writing  3p200set1ch
#
# writing  3p10stein27
#
# writing  3p50stein27
#
# writing  3p100stein27
#
# writing  3p200stein27
#
# writing  3p10stein45
#
# writing  3p50stein45
#
# writing  3p100stein45
#
# writing  3p200stein45
#
# writing  3p10vpm1
#
# writing  3p50vpm1
#
# writing  3p100vpm1
#
# writing  3p200vpm1
#
# writing  3p10vpm2
#
# writing  3p50vpm2
#
# writing  3p100vpm2
#
# writing  3p200vpm2
#
# writing  4p10air03
#
# writing  4p50air03
#
# writing  4p100air03
#
# writing  4p200air03
#
# writing  4p10bell5
#
# writing  4p50bell5
#
# writing  4p100bell5
#
# writing  4p200bell5
#
# writing  4p10dcmulti
#
# writing  4p50dcmulti
#
# writing  4p100dcmulti
#
# writing  4p200dcmulti
#
# writing  4p10fiber
#
# writing  4p50fiber
#
# writing  4p100fiber
#
# writing  4p200fiber
#
# writing  4p10fixnet6
#
# writing  4p50fixnet6
#
# writing  4p100fixnet6
#
# writing  4p200fixnet6
#
# writing  4p10gen
#
# writing  4p50gen
#
# writing  4p100gen
#
# writing  4p200gen
#
# writing  4p10gesa3
#
# writing  4p50gesa3
#
# writing  4p100gesa3
#
# writing  4p200gesa3
#
# writing  4p10gt2
#
# writing  4p50gt2
#
# writing  4p100gt2
#
# writing  4p200gt2
#
# writing  4p10khb05250
#
# writing  4p50khb05250
#
# writing  4p100khb05250
#
# writing  4p200khb05250
#
# writing  4p10l152lav
#
# writing  4p50l152lav
#
# writing  4p100l152lav
#
# writing  4p200l152lav
#
# writing  4p10misc03
#
# writing  4p50misc03
#
# writing  4p100misc03
#
# writing  4p200misc03
#
# writing  4p10misc06
#
# writing  4p50misc06
#
# writing  4p100misc06
#
# writing  4p200misc06
#
# writing  4p10mod008
#
# writing  4p50mod008
#
# writing  4p100mod008
#
# writing  4p200mod008
#
# writing  4p10mod010
#
# writing  4p50mod010
#
# writing  4p100mod010
#
# writing  4p200mod010
#
# writing  4p10p0033
#
# writing  4p50p0033
#
# writing  4p100p0033
#
# writing  4p200p0033
#
# writing  4p10p0201
#
# writing  4p50p0201
#
# writing  4p100p0201
#
# writing  4p200p0201
#
# writing  4p10p0548
#
# writing  4p50p0548
#
# writing  4p100p0548
#
# writing  4p200p0548
#
# writing  4p10pp08a
#
# writing  4p50pp08a
#
# writing  4p100pp08a
#
# writing  4p200pp08a
#
# writing  4p10pp08aCUTS
#
# writing  4p50pp08aCUTS
#
# writing  4p100pp08aCUTS
#
# writing  4p200pp08aCUTS
#
# writing  4p10qnet1_o
#
# writing  4p50qnet1_o
#
# writing  4p100qnet1_o
#
# writing  4p200qnet1_o
#
# writing  4p10qnet1
#
# writing  4p50qnet1
#
# writing  4p100qnet1
#
# writing  4p200qnet1
#
# writing  4p10rgn
#
# writing  4p50rgn
#
# writing  4p100rgn
#
# writing  4p200rgn
#
# writing  4p10set1ch
#
# writing  4p50set1ch
#
# writing  4p100set1ch
#
# writing  4p200set1ch
#
# writing  4p10stein27
#
# writing  4p50stein27
#
# writing  4p100stein27
#
# writing  4p200stein27
#
# writing  4p10stein45
#
# writing  4p50stein45
#
# writing  4p100stein45
#
# writing  4p200stein45
#
# writing  4p10vpm1
#
# writing  4p50vpm1
#
# writing  4p100vpm1
#
# writing  4p200vpm1
#
# writing  4p10vpm2
#
# writing  4p50vpm2
#
# writing  4p100vpm2
#
# writing  4p200vpm2
#
# writing  5p10air03
#
# writing  5p50air03
#
# writing  5p100air03
#
# writing  5p200air03
#
# writing  5p10bell5
#
# writing  5p50bell5
#
# writing  5p100bell5
#
# writing  5p200bell5
#
# writing  5p10dcmulti
#
# writing  5p50dcmulti
#
# writing  5p100dcmulti
#
# writing  5p200dcmulti
#
# writing  5p10fiber
#
# writing  5p50fiber
#
# writing  5p100fiber
#
# writing  5p200fiber
#
# writing  5p10fixnet6
#
# writing  5p50fixnet6
#
# writing  5p100fixnet6
#
# writing  5p200fixnet6
#
# writing  5p10gen
#
# writing  5p50gen
#
# writing  5p100gen
#
# writing  5p200gen
#
# writing  5p10gesa3
#
# writing  5p50gesa3
#
# writing  5p100gesa3
#
# writing  5p200gesa3
#
# writing  5p10gt2
#
# writing  5p50gt2
#
# writing  5p100gt2
#
# writing  5p200gt2
#
# writing  5p10khb05250
#
# writing  5p50khb05250
#
# writing  5p100khb05250
#
# writing  5p200khb05250
#
# writing  5p10l152lav
#
# writing  5p50l152lav
#
# writing  5p100l152lav
#
# writing  5p200l152lav
#
# writing  5p10misc03
#
# writing  5p50misc03
#
# writing  5p100misc03
#
# writing  5p200misc03
#
# writing  5p10misc06
#
# writing  5p50misc06
#
# writing  5p100misc06
#
# writing  5p200misc06
#
# writing  5p10mod008
#
# writing  5p50mod008
#
# writing  5p100mod008
#
# writing  5p200mod008
#
# writing  5p10mod010
#
# writing  5p50mod010
#
# writing  5p100mod010
#
# writing  5p200mod010
#
# writing  5p10p0033
#
# writing  5p50p0033
#
# writing  5p100p0033
#
# writing  5p200p0033
#
# writing  5p10p0201
#
# writing  5p50p0201
#
# writing  5p100p0201
#
# writing  5p200p0201
#
# writing  5p10p0548
#
# writing  5p50p0548
#
# writing  5p100p0548
#
# writing  5p200p0548
#
# writing  5p10pp08a
#
# writing  5p50pp08a
#
# writing  5p100pp08a
#
# writing  5p200pp08a
#
# writing  5p10pp08aCUTS
#
# writing  5p50pp08aCUTS
#
# writing  5p100pp08aCUTS
#
# writing  5p200pp08aCUTS
#
# writing  5p10qnet1_o
#
# writing  5p50qnet1_o
#
# writing  5p100qnet1_o
#
# writing  5p200qnet1_o
#
# writing  5p10qnet1
#
# writing  5p50qnet1
#
# writing  5p100qnet1
#
# writing  5p200qnet1
#
# writing  5p10rgn
#
# writing  5p50rgn
#
# writing  5p100rgn
#
# writing  5p200rgn
#
# writing  5p10set1ch
#
# writing  5p50set1ch
#
# writing  5p100set1ch
#
# writing  5p200set1ch
#
# writing  5p10stein27
#
# writing  5p50stein27
#
# writing  5p100stein27
#
# writing  5p200stein27
#
# writing  5p10stein45
#
# writing  5p50stein45
#
# writing  5p100stein45
#
# writing  5p200stein45
#
# writing  5p10vpm1
#
# writing  5p50vpm1
#
# writing  5p100vpm1
#
# writing  5p200vpm1
#
# writing  5p10vpm2
#
# writing  5p50vpm2
#
# writing  5p100vpm2
#
# writing  5p200vpm2
#
# writing  6p10air03
#
# writing  6p50air03
#
# writing  6p100air03
#
# writing  6p200air03
#
# writing  6p10bell5
#
# writing  6p50bell5
#
# writing  6p100bell5
#
# writing  6p200bell5
#
# writing  6p10dcmulti
#
# writing  6p50dcmulti
#
# writing  6p100dcmulti
#
# writing  6p200dcmulti
#
# writing  6p10fiber
#
# writing  6p50fiber
#
# writing  6p100fiber
#
# writing  6p200fiber
#
# writing  6p10fixnet6
#
# writing  6p50fixnet6
#
# writing  6p100fixnet6
#
# writing  6p200fixnet6
#
# writing  6p10gen
#
# writing  6p50gen
#
# writing  6p100gen
#
# writing  6p200gen
#
# writing  6p10gesa3
#
# writing  6p50gesa3
#
# writing  6p100gesa3
#
# writing  6p200gesa3
#
# writing  6p10gt2
#
# writing  6p50gt2
#
# writing  6p100gt2
#
# writing  6p200gt2
#
# writing  6p10khb05250
#
# writing  6p50khb05250
#
# writing  6p100khb05250
#
# writing  6p200khb05250
#
# writing  6p10l152lav
#
# writing  6p50l152lav
#
# writing  6p100l152lav
#
# writing  6p200l152lav
#
# writing  6p10misc03
#
# writing  6p50misc03
#
# writing  6p100misc03
#
# writing  6p200misc03
#
# writing  6p10misc06
#
# writing  6p50misc06
#
# writing  6p100misc06
#
# writing  6p200misc06
#
# writing  6p10mod008
#
# writing  6p50mod008
#
# writing  6p100mod008
#
# writing  6p200mod008
# writing  6p10mod010
#
# writing  6p50mod010
#
# writing  6p100mod010
#
# writing  6p200mod010
#
# writing  6p10p0033
#
# writing  6p50p0033
#
# writing  6p100p0033
#
# writing  6p200p0033
#
# writing  6p10p0201
#
# writing  6p50p0201
#
# writing  6p100p0201
#
# writing  6p200p0201
#
# writing  6p10p0548
#
# writing  6p50p0548
#
# writing  6p100p0548
#
# writing  6p200p0548
#
# writing  6p10pp08a
#
# writing  6p50pp08a
#
# writing  6p100pp08a
#
# writing  6p200pp08a
#
# writing  6p10pp08aCUTS
#
# writing  6p50pp08aCUTS
#
# writing  6p100pp08aCUTS
#
# writing  6p200pp08aCUTS
#
# writing  6p10qnet1_o
#
# writing  6p50qnet1_o
#
# writing  6p100qnet1_o
#
# writing  6p200qnet1_o
#
# writing  6p10qnet1
#
# writing  6p50qnet1
#
# writing  6p100qnet1
#
# writing  6p200qnet1
#
# writing  6p10rgn
#
# writing  6p50rgn
#
# writing  6p100rgn
#
# writing  6p200rgn
#
# writing  6p10set1ch
#
# writing  6p50set1ch
#
# writing  6p100set1ch
#
# writing  6p200set1ch
#
# writing  6p10stein27
#
# writing  6p50stein27
#
# writing  6p100stein27
#
# writing  6p200stein27
#
# writing  6p10stein45
#
# writing  6p50stein45
#
# writing  6p100stein45
#
# writing  6p200stein45
#
# writing  6p10vpm1
#
# writing  6p50vpm1
#
# writing  6p100vpm1
#
# writing  6p200vpm1
#
# writing  6p10vpm2
#
# writing  6p50vpm2
#
# writing  6p100vpm2
#
# writing  6p200vpm2
#
# writing  7p10air03
#
# writing  7p50air03
#
# writing  7p100air03
#
# writing  7p200air03
#
# writing  7p10bell5
#
# writing  7p50bell5
#
# writing  7p100bell5
#
# writing  7p200bell5
#
# writing  7p10dcmulti
#
# writing  7p50dcmulti
#
# writing  7p100dcmulti
#
# writing  7p200dcmulti
#
# writing  7p10fiber
#
# writing  7p50fiber
#
# writing  7p100fiber
#
# writing  7p200fiber
#
# writing  7p10fixnet6
#
# writing  7p50fixnet6
#
# writing  7p100fixnet6
#
# writing  7p200fixnet6
#
# writing  7p10gen
#
# writing  7p50gen
#
# writing  7p100gen
#
# writing  7p200gen
#
# writing  7p10gesa3
#
# writing  7p50gesa3
#
# writing  7p100gesa3
#
# writing  7p200gesa3
#
# writing  7p10gt2
#
# writing  7p50gt2
#
# writing  7p100gt2
#
# writing  7p200gt2
#
# writing  7p10khb05250
#
# writing  7p50khb05250
#
# writing  7p100khb05250
#
# writing  7p200khb05250
#
# writing  7p10l152lav
#
# writing  7p50l152lav
#
# writing  7p100l152lav
#
# writing  7p200l152lav
#
# writing  7p10misc03
#
# writing  7p50misc03
#
# writing  7p100misc03
#
# writing  7p200misc03
#
# writing  7p10misc06
#
# writing  7p50misc06
#
# writing  7p100misc06
#
# writing  7p200misc06
#
# writing  7p10mod008
#
# writing  7p50mod008
#
# writing  7p100mod008
#
# writing  7p200mod008
#
# writing  7p10mod010
#
# writing  7p50mod010
#
# writing  7p100mod010
#
# writing  7p200mod010
#
# writing  7p10p0033
#
# writing  7p50p0033
#
# writing  7p100p0033
#
# writing  7p200p0033
#
# writing  7p10p0201
#
# writing  7p50p0201
#
# writing  7p100p0201
#
# writing  7p200p0201
#
# writing  7p10p0548
#
# writing  7p50p0548
#
# writing  7p100p0548
#
# writing  7p200p0548
#
# writing  7p10pp08a
#
# writing  7p50pp08a
#
# writing  7p100pp08a
#
# writing  7p200pp08a
#
# writing  7p10pp08aCUTS
#
# writing  7p50pp08aCUTS
#
# writing  7p100pp08aCUTS
#
# writing  7p200pp08aCUTS
#
# writing  7p10qnet1_o
#
# writing  7p50qnet1_o
#
# writing  7p100qnet1_o
#
# writing  7p200qnet1_o
#
# writing  7p10qnet1
#
# writing  7p50qnet1
#
# writing  7p100qnet1
#
# writing  7p200qnet1
#
# writing  7p10rgn
#
# writing  7p50rgn
#
# writing  7p100rgn
#
# writing  7p200rgn
#
# writing  7p10set1ch
#
# writing  7p50set1ch
#
# writing  7p100set1ch
#
# writing  7p200set1ch
#
# writing  7p10stein27
#
# writing  7p50stein27
#
# writing  7p100stein27
#
# writing  7p200stein27
#
# writing  7p10stein45
#
# writing  7p50stein45
#
# writing  7p100stein45
#
# writing  7p200stein45
#
# writing  7p10vpm1
#
# writing  7p50vpm1
#
# writing  7p100vpm1
#
# writing  7p200vpm1
#
# writing  7p10vpm2
#
# writing  7p50vpm2
#
# writing  7p100vpm2
#
# writing  7p200vpm2
#
# writing  8p10air03
#
# writing  8p50air03
#
# writing  8p100air03
#
# writing  8p200air03
#
# writing  8p10bell5
#
# writing  8p50bell5
#
# writing  8p100bell5
#
# writing  8p200bell5
#
# writing  8p10dcmulti
#
# writing  8p50dcmulti
#
# writing  8p100dcmulti
#
# writing  8p200dcmulti
#
# writing  8p10fiber
#
# writing  8p50fiber
#
# writing  8p100fiber
#
# writing  8p200fiber
#
# writing  8p10fixnet6
#
# writing  8p50fixnet6
#
# writing  8p100fixnet6
#
# writing  8p200fixnet6
#
# writing  8p10gen
#
# writing  8p50gen
#
# writing  8p100gen
#
# writing  8p200gen
#
# writing  8p10gesa3
#
# writing  8p50gesa3
#
# writing  8p100gesa3
#
# writing  8p200gesa3
#
# writing  8p10gt2
#
# writing  8p50gt2
#
# writing  8p100gt2
#
# writing  8p200gt2
#
# writing  8p10khb05250
#
# writing  8p50khb05250
#
# writing  8p100khb05250
#
# writing  8p200khb05250
#
# writing  8p10l152lav
#
# writing  8p50l152lav
#
# writing  8p100l152lav
#
# writing  8p200l152lav
#
# writing  8p10misc03
#
# writing  8p50misc03
#
# writing  8p100misc03
#
# writing  8p200misc03
#
# writing  8p10misc06
#
# writing  8p50misc06
#
# writing  8p100misc06
#
# writing  8p200misc06
#
# writing  8p10mod008
#
# writing  8p50mod008
#
# writing  8p100mod008
#
# writing  8p200mod008
#
# writing  8p10mod010
#
# writing  8p50mod010
#
# writing  8p100mod010
#
# writing  8p200mod010
#
# writing  8p10p0033
#
# writing  8p50p0033
#
# writing  8p100p0033
#
# writing  8p200p0033
#
# writing  8p10p0201
#
# writing  8p50p0201
#
# writing  8p100p0201
#
# writing  8p200p0201
#
# writing  8p10p0548
#
# writing  8p50p0548
#
# writing  8p100p0548
#
# writing  8p200p0548
#
# writing  8p10pp08a
#
# writing  8p50pp08a
#
# writing  8p100pp08a
#
# writing  8p200pp08a
#
# writing  8p10pp08aCUTS
#
# writing  8p50pp08aCUTS
#
# writing  8p100pp08aCUTS
#
# writing  8p200pp08aCUTS
#
# writing  8p10qnet1_o
#
# writing  8p50qnet1_o
#
# writing  8p100qnet1_o
#
# writing  8p200qnet1_o
#
# writing  8p10qnet1
#
# writing  8p50qnet1
#
# writing  8p100qnet1
#
# writing  8p200qnet1
#
# writing  8p10rgn
#
# writing  8p50rgn
#
# writing  8p100rgn
#
# writing  8p200rgn
#
# writing  8p10set1ch
#
# writing  8p50set1ch
#
# writing  8p100set1ch
#
# writing  8p200set1ch
#
# writing  8p10stein27
#
# writing  8p50stein27
#
# writing  8p100stein27
#
# writing  8p200stein27
#
# writing  8p10stein45
#
# writing  8p50stein45
#
# writing  8p100stein45
#
# writing  8p200stein45
#
# writing  8p10vpm1
#
# writing  8p50vpm1
#
# writing  8p100vpm1
#
# writing  8p200vpm1
#
# writing  8p10vpm2
#
# writing  8p50vpm2
#
# writing  8p100vpm2
#
# writing  8p200vpm2
#
# writing  9p10air03
#
# writing  9p50air03
#
# writing  9p100air03
#
# writing  9p200air03
#
# writing  9p10bell5
#
# writing  9p50bell5
#
# writing  9p100bell5
#
# writing  9p200bell5
#
# writing  9p10dcmulti
#
# writing  9p50dcmulti
#
# writing  9p100dcmulti
#
# writing  9p200dcmulti
#
# writing  9p10fiber
#
# writing  9p50fiber
#
# writing  9p100fiber
#
# writing  9p200fiber
#
# writing  9p10fixnet6
#
# writing  9p50fixnet6
#
# writing  9p100fixnet6
#
# writing  9p200fixnet6
#
# writing  9p10gen
#
# writing  9p50gen
#
# writing  9p100gen
#
# writing  9p200gen
#
# writing  9p10gesa3
#
# writing  9p50gesa3
#
# writing  9p100gesa3
#
# writing  9p200gesa3
#
# writing  9p10gt2
#
# writing  9p50gt2
#
# writing  9p100gt2
#
# writing  9p200gt2
#
# writing  9p10khb05250
#
# writing  9p50khb05250
#
# writing  9p100khb05250
#
# writing  9p200khb05250
#
# writing  9p10l152lav
#
# writing  9p50l152lav
#
# writing  9p100l152lav
#
# writing  9p200l152lav
#
# writing  9p10misc03
#
# writing  9p50misc03
#
# writing  9p100misc03
#
# writing  9p200misc03
#
# writing  9p10misc06
#
# writing  9p50misc06
#
# writing  9p100misc06
#
# writing  9p200misc06
#
# writing  9p10mod008
#
# writing  9p50mod008
#
# writing  9p100mod008
#
# writing  9p200mod008
#
# writing  9p10mod010
#
# writing  9p50mod010
#
# writing  9p100mod010
#
# writing  9p200mod010
#
# writing  9p10p0033
#
# writing  9p50p0033
#
# writing  9p100p0033
#
# writing  9p200p0033
#
# writing  9p10p0201
#
# writing  9p50p0201
#
# writing  9p100p0201
#
# writing  9p200p0201
#
# writing  9p10p0548
#
# writing  9p50p0548
#
# writing  9p100p0548
#
# writing  9p200p0548
#
# writing  9p10pp08a
#
# writing  9p50pp08a
#
# writing  9p100pp08a
#
# writing  9p200pp08a
#
# writing  9p10pp08aCUTS
#
# writing  9p50pp08aCUTS
#
# writing  9p100pp08aCUTS
#
# writing  9p200pp08aCUTS
#
# writing  9p10qnet1_o
#
# writing  9p50qnet1_o
#
# writing  9p100qnet1_o
#
# writing  9p200qnet1_o
#
# writing  9p10qnet1
#
# writing  9p50qnet1
#
# writing  9p100qnet1
#
# writing  9p200qnet1
#
# writing  9p10rgn
#
# writing  9p50rgn
#
# writing  9p100rgn
#
# writing  9p200rgn
#
# writing  9p10set1ch
#
# writing  9p50set1ch
#
# writing  9p100set1ch
#
# writing  9p200set1ch
#
# writing  9p10stein27
#
# writing  9p50stein27
#
# writing  9p100stein27
#
# writing  9p200stein27
#
# writing  9p10stein45
#
# writing  9p50stein45
#
# writing  9p100stein45
#
# writing  9p200stein45
#
# writing  9p10vpm1
#
# writing  9p50vpm1
#
# writing  9p100vpm1
#
# writing  9p200vpm1
#
# writing  9p10vpm2
#
# writing  9p50vpm2
#
# writing  9p100vpm2
#
# writing  9p200vpm2
#
# writing  10p10air03
#
# writing  10p50air03
#
# writing  10p100air03
#
# writing  10p200air03
#
# writing  10p10bell5
#
# writing  10p50bell5
#
# writing  10p100bell5
#
# writing  10p200bell5
#
# writing  10p10dcmulti
#
# writing  10p50dcmulti
#
# writing  10p100dcmulti
#
# writing  10p200dcmulti
#
# writing  10p10fiber
#
# writing  10p50fiber
#
# writing  10p100fiber
#
# writing  10p200fiber
#
# writing  10p10fixnet6
#
# writing  10p50fixnet6
#
# writing  10p100fixnet6
#
# writing  10p200fixnet6
#
# writing  10p10gen
#
# writing  10p50gen
#
# writing  10p100gen
#
# writing  10p200gen
#
# writing  10p10gesa3
#
# writing  10p50gesa3
#
# writing  10p100gesa3
#
# writing  10p200gesa3
#
# writing  10p10gt2
#
# writing  10p50gt2
#
# writing  10p100gt2
#
# writing  10p200gt2
#
# writing  10p10khb05250
#
# writing  10p50khb05250
#
# writing  10p100khb05250
#
# writing  10p200khb05250
#
# writing  10p10l152lav
#
# writing  10p50l152lav
#
# writing  10p100l152lav
#
# writing  10p200l152lav
#
# writing  10p10misc03
#
# writing  10p50misc03
#
# writing  10p100misc03
#
# writing  10p200misc03
#
# writing  10p10misc06
#
# writing  10p50misc06
#
# writing  10p100misc06
#
# writing  10p200misc06
#
# writing  10p10mod008
#
# writing  10p50mod008
#
# writing  10p100mod008
#
# writing  10p200mod008
#
# writing  10p10mod010
#
# writing  10p50mod010
#
# writing  10p100mod010
#
# writing  10p200mod010
#
# writing  10p10p0033
#
# writing  10p50p0033
#
# writing  10p100p0033
#
# writing  10p200p0033
#
# writing  10p10p0201
#
# writing  10p50p0201
#
# writing  10p100p0201
#
# writing  10p200p0201
#
# writing  10p10p0548
#
# writing  10p50p0548
#
# writing  10p100p0548
#
# writing  10p200p0548
#
# writing  10p10pp08a
#
# writing  10p50pp08a
#
# writing  10p100pp08a
#
# writing  10p200pp08a
#
# writing  10p10pp08aCUTS
#
# writing  10p50pp08aCUTS
#
# writing  10p100pp08aCUTS
#
# writing  10p200pp08aCUTS
#
# writing  10p10qnet1_o
#
# writing  10p50qnet1_o
#
# writing  10p100qnet1_o
#
# writing  10p200qnet1_o
#
# writing  10p10qnet1
#
# writing  10p50qnet1
#
# writing  10p100qnet1
#
# writing  10p200qnet1
#
# writing  10p10rgn
#
# writing  10p50rgn
#
# writing  10p100rgn
#
# writing  10p200rgn
#
# writing  10p10set1ch
#
# writing  10p50set1ch
#
# writing  10p100set1ch
#
# writing  10p200set1ch
#
# writing  10p10stein27
#
# writing  10p50stein27
#
# writing  10p100stein27
#
# writing  10p200stein27
#
# writing  10p10stein45
#
# writing  10p50stein45
#
# writing  10p100stein45
#
# writing  10p200stein45
#
# writing  10p10vpm1
#
# writing  10p50vpm1
#
# writing  10p100vpm1
#
# writing  10p200vpm1
#
# writing  10p10vpm2
#
# writing  10p50vpm2
#
# writing  10p100vpm2
#
# writing  10p200vpm2

# %% [markdown]
# ### - INPUT FILES

# %% [markdown]
# #### - Input Format

# %%
# solver, SCIP
# nodeType, 0, 1
# alphaValue, 0.05
# optimizationProblem, 23588.mps, bppc8-02.mps, exp-1-500-5-5.mps, mtest4ma.mps, neos-1425699.mps, neos17.mps, nexp-50-20-1-1.mps, sp150x300d.mps,
# requestedNumberSolutions, 10000
# percentNearOptimal, 0.01
# Verbosity, 1
# beta, 1
# priorotizedParam, beta, #, The prioritized parameter is set at given value
# solutioncutoff, 0.2
# depthcutoff, 0
# computeDiversity, 1, #, 0 means compute the diversities of captured solutions 1 means write the captured solutions to .csv file
# computeDiversityFromCsv, 0, #, 0 means we DON'T Have a .csv file hence run GAMS or SCIP, 1 means we are given a .csv file with solutions hence just compute the diversity of the k most diverse solutions; k is represented by the parameter - requestedNumberSolutions
# csvFile,
# pMostDiverseSolutions, 10

# %%
percentNearOptimal = {'1p':0.01,'2p':0.02,'3p':0.03,'4p':0.04,'5p':0.05,'6p':0.06,'7p':0.07,'8p':0.08,'9p':0.09,'10p':0.10}

# %%
import os
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/inputFiles

# %%
cwd = os.getcwd() + '/Train/inputFiles'
print(cwd)

for percent in percentages:
    
    for problem in trainSet:
        
        for j in numNearOptimal:
            
            testFileName = percent + str(j) + problem + '.txt'
            fullFName = cwd  +'/' + testFileName
            
            print('writing ',testFileName, '\n')
            with open(fullFName,'w') as f:
                f.write('solver, SCIP')
                f.write('\n')
                f.write('nodeType, 0, 1')
                f.write('\n')
                f.write('alphaValue, 0.01, 0.94, 0.18, 0.95')
                f.write('\n')
                f.write('optimizationProblem, ' + problem + ".mps")
                f.write('\n')
                f.write('requestedNumberSolutions, ' + str(j))
                f.write('\n')
                f.write('percentNearOptimal, ' + str(percentNearOptimal.get(percent)))
                f.write('\n')
                f.write('Verbosity, 1')
                f.write('\n')
                f.write('beta, 0.06, 0.8, 0.99')
                f.write('\n')
                f.write('priorotizedParam, beta, #, The prioritized parameter is set at given value')
                f.write('\n')
                f.write('solutioncutoff, 0.05, 0.8, 0.7, 0.2')
                f.write('\n')
                f.write('depthcutoff, 0')
                f.write('\n')
                f.write('computeDiversity, 1, #, 0 means compute the diversities of captured solutions 1 means write the captured solutions to .csv file')
                f.write('\n')
                f.write('computeDiversityFromCsv, 0, #, 0 means we DONT Have a .csv file hence run GAMS or SCIP, 1 means we are given a .csv file with solutions hence just compute the diversity of the k most diverse solutions; k is represented by the parameter - requestedNumberSolutions')
                f.write('\n')
                f.write('csvFile,')
                f.write('\n')
                f.write('pMostDiverseSolutions, 10')
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/inputFiles
# writing  1p10air03.txt
#
# writing  1p50air03.txt
#
# writing  1p100air03.txt
#
# writing  1p200air03.txt
#
# writing  1p10bell5.txt
#
# writing  1p50bell5.txt
#
# writing  1p100bell5.txt
#
# writing  1p200bell5.txt
#
# writing  1p10dcmulti.txt
#
# writing  1p50dcmulti.txt
#
# writing  1p100dcmulti.txt
#
# writing  1p200dcmulti.txt
#
# writing  1p10fiber.txt
#
# writing  1p50fiber.txt
#
# writing  1p100fiber.txt
#
# writing  1p200fiber.txt
#
# writing  1p10fixnet6.txt
#
# writing  1p50fixnet6.txt
#
# writing  1p100fixnet6.txt
#
# writing  1p200fixnet6.txt
#
# writing  1p10gen.txt
#
# writing  1p50gen.txt
#
# writing  1p100gen.txt
#
# writing  1p200gen.txt
#
# writing  1p10gesa3.txt
#
# writing  1p50gesa3.txt
#
# writing  1p100gesa3.txt
#
# writing  1p200gesa3.txt
#
# writing  1p10gt2.txt
#
# writing  1p50gt2.txt
#
# writing  1p100gt2.txt
#
# writing  1p200gt2.txt
#
# writing  1p10khb05250.txt
#
# writing  1p50khb05250.txt
#
# writing  1p100khb05250.txt
#
# writing  1p200khb05250.txt
#
# writing  1p10l152lav.txt
#
# writing  1p50l152lav.txt
#
# writing  1p100l152lav.txt
#
# writing  1p200l152lav.txt
#
# writing  1p10misc03.txt
#
# writing  1p50misc03.txt
#
# writing  1p100misc03.txt
#
# writing  1p200misc03.txt
#
# writing  1p10misc06.txt
#
# writing  1p50misc06.txt
#
# writing  1p100misc06.txt
#
# writing  1p200misc06.txt
#
# writing  1p10mod008.txt
#
# writing  1p50mod008.txt
#
# writing  1p100mod008.txt
#
# writing  1p200mod008.txt
#
# writing  1p10mod010.txt
#
# writing  1p50mod010.txt
#
# writing  1p100mod010.txt
#
# writing  1p200mod010.txt
#
# writing  1p10p0033.txt
#
# writing  1p50p0033.txt
#
# writing  1p100p0033.txt
#
# writing  1p200p0033.txt
#
# writing  1p10p0201.txt
#
# writing  1p50p0201.txt
#
# writing  1p100p0201.txt
#
# writing  1p200p0201.txt
#
# writing  1p10p0548.txt
#
# writing  1p50p0548.txt
#
# writing  1p100p0548.txt
#
# writing  1p200p0548.txt
#
# writing  1p10pp08a.txt
#
# writing  1p50pp08a.txt
#
# writing  1p100pp08a.txt
#
# writing  1p200pp08a.txt
#
# writing  1p10pp08aCUTS.txt
#
# writing  1p50pp08aCUTS.txt
#
# writing  1p100pp08aCUTS.txt
#
# writing  1p200pp08aCUTS.txt
#
# writing  1p10qnet1_o.txt
#
# writing  1p50qnet1_o.txt
#
# writing  1p100qnet1_o.txt
#
# writing  1p200qnet1_o.txt
#
# writing  1p10qnet1.txt
#
# writing  1p50qnet1.txt
#
# writing  1p100qnet1.txt
#
# writing  1p200qnet1.txt
#
# writing  1p10rgn.txt
#
# writing  1p50rgn.txt
#
# writing  1p100rgn.txt
#
# writing  1p200rgn.txt
#
# writing  1p10set1ch.txt
#
# writing  1p50set1ch.txt
#
# writing  1p100set1ch.txt
#
# writing  1p200set1ch.txt
#
# writing  1p10stein27.txt
#
# writing  1p50stein27.txt
#
# writing  1p100stein27.txt
#
# writing  1p200stein27.txt
#
# writing  1p10stein45.txt
#
# writing  1p50stein45.txt
#
# writing  1p100stein45.txt
#
# writing  1p200stein45.txt
#
# writing  1p10vpm1.txt
#
# writing  1p50vpm1.txt
#
# writing  1p100vpm1.txt
#
# writing  1p200vpm1.txt
#
# writing  1p10vpm2.txt
#
# writing  1p50vpm2.txt
#
# writing  1p100vpm2.txt
#
# writing  1p200vpm2.txt
#
# writing  2p10air03.txt
#
# writing  2p50air03.txt
#
# writing  2p100air03.txt
#
# writing  2p200air03.txt
#
# writing  2p10bell5.txt
#
# writing  2p50bell5.txt
#
# writing  2p100bell5.txt
#
# writing  2p200bell5.txt
#
# writing  2p10dcmulti.txt
#
# writing  2p50dcmulti.txt
#
# writing  2p100dcmulti.txt
#
# writing  2p200dcmulti.txt
#
# writing  2p10fiber.txt
#
# writing  2p50fiber.txt
#
# writing  2p100fiber.txt
#
# writing  2p200fiber.txt
#
# writing  2p10fixnet6.txt
#
# writing  2p50fixnet6.txt
#
# writing  2p100fixnet6.txt
#
# writing  2p200fixnet6.txt
#
# writing  2p10gen.txt
#
# writing  2p50gen.txt
#
# writing  2p100gen.txt
#
# writing  2p200gen.txt
#
# writing  2p10gesa3.txt
#
# writing  2p50gesa3.txt
#
# writing  2p100gesa3.txt
#
# writing  2p200gesa3.txt
#
# writing  2p10gt2.txt
#
# writing  2p50gt2.txt
#
# writing  2p100gt2.txt
#
# writing  2p200gt2.txt
#
# writing  2p10khb05250.txt
#
# writing  2p50khb05250.txt
#
# writing  2p100khb05250.txt
#
# writing  2p200khb05250.txt
#
# writing  2p10l152lav.txt
#
# writing  2p50l152lav.txt
#
# writing  2p100l152lav.txt
#
# writing  2p200l152lav.txt
#
# writing  2p10misc03.txt
#
# writing  2p50misc03.txt
#
# writing  2p100misc03.txt
#
# writing  2p200misc03.txt
#
# writing  2p10misc06.txt
#
# writing  2p50misc06.txt
#
# writing  2p100misc06.txt
#
# writing  2p200misc06.txt
#
# writing  2p10mod008.txt
#
# writing  2p50mod008.txt
#
# writing  2p100mod008.txt
#
# writing  2p200mod008.txt
#
# writing  2p10mod010.txt
#
# writing  2p50mod010.txt
#
# writing  2p100mod010.txt
#
# writing  2p200mod010.txt
#
# writing  2p10p0033.txt
#
# writing  2p50p0033.txt
#
# writing  2p100p0033.txt
#
# writing  2p200p0033.txt
#
# writing  2p10p0201.txt
#
# writing  2p50p0201.txt
#
# writing  2p100p0201.txt
#
# writing  2p200p0201.txt
#
# writing  2p10p0548.txt
#
# writing  2p50p0548.txt
#
# writing  2p100p0548.txt
#
# writing  2p200p0548.txt
#
# writing  2p10pp08a.txt
#
# writing  2p50pp08a.txt
#
# writing  2p100pp08a.txt
#
# writing  2p200pp08a.txt
#
# writing  2p10pp08aCUTS.txt
#
# writing  2p50pp08aCUTS.txt
#
# writing  2p100pp08aCUTS.txt
#
# writing  2p200pp08aCUTS.txt
#
# writing  2p10qnet1_o.txt
#
# writing  2p50qnet1_o.txt
#
# writing  2p100qnet1_o.txt
#
# writing  2p200qnet1_o.txt
#
# writing  2p10qnet1.txt
#
# writing  2p50qnet1.txt
#
# writing  2p100qnet1.txt
#
# writing  2p200qnet1.txt
#
# writing  2p10rgn.txt
#
# writing  2p50rgn.txt
#
# writing  2p100rgn.txt
#
# writing  2p200rgn.txt
#
# writing  2p10set1ch.txt
#
# writing  2p50set1ch.txt
#
# writing  2p100set1ch.txt
#
# writing  2p200set1ch.txt
#
# writing  2p10stein27.txt
#
# writing  2p50stein27.txt
#
# writing  2p100stein27.txt
#
# writing  2p200stein27.txt
#
# writing  2p10stein45.txt
#
# writing  2p50stein45.txt
#
# writing  2p100stein45.txt
#
# writing  2p200stein45.txt
#
# writing  2p10vpm1.txt
#
# writing  2p50vpm1.txt
#
# writing  2p100vpm1.txt
#
# writing  2p200vpm1.txt
#
# writing  2p10vpm2.txt
#
# writing  2p50vpm2.txt
#
# writing  2p100vpm2.txt
#
# writing  2p200vpm2.txt
#
# writing  3p10air03.txt
#
# writing  3p50air03.txt
#
# writing  3p100air03.txt
#
# writing  3p200air03.txt
#
# writing  3p10bell5.txt
#
# writing  3p50bell5.txt
#
# writing  3p100bell5.txt
#
# writing  3p200bell5.txt
#
# writing  3p10dcmulti.txt
#
# writing  3p50dcmulti.txt
#
# writing  3p100dcmulti.txt
#
# writing  3p200dcmulti.txt
#
# writing  3p10fiber.txt
#
# writing  3p50fiber.txt
#
# writing  3p100fiber.txt
#
# writing  3p200fiber.txt
#
# writing  3p10fixnet6.txt
#
# writing  3p50fixnet6.txt
#
# writing  3p100fixnet6.txt
#
# writing  3p200fixnet6.txt
#
# writing  3p10gen.txt
#
# writing  3p50gen.txt
#
# writing  3p100gen.txt
#
# writing  3p200gen.txt
#
# writing  3p10gesa3.txt
#
# writing  3p50gesa3.txt
#
# writing  3p100gesa3.txt
#
# writing  3p200gesa3.txt
#
# writing  3p10gt2.txt
#
# writing  3p50gt2.txt
#
# writing  3p100gt2.txt
#
# writing  3p200gt2.txt
#
# writing  3p10khb05250.txt
#
# writing  3p50khb05250.txt
#
# writing  3p100khb05250.txt
#
# writing  3p200khb05250.txt
#
# writing  3p10l152lav.txt
#
# writing  3p50l152lav.txt
#
# writing  3p100l152lav.txt
#
# writing  3p200l152lav.txt
#
# writing  3p10misc03.txt
#
# writing  3p50misc03.txt
#
# writing  3p100misc03.txt
#
# writing  3p200misc03.txt
#
# writing  3p10misc06.txt
#
# writing  3p50misc06.txt
#
# writing  3p100misc06.txt
#
# writing  3p200misc06.txt
#
# writing  3p10mod008.txt
#
# writing  3p50mod008.txt
#
# writing  3p100mod008.txt
#
# writing  3p200mod008.txt
#
# writing  3p10mod010.txt
#
# writing  3p50mod010.txt
#
# writing  3p100mod010.txt
#
# writing  3p200mod010.txt
#
# writing  3p10p0033.txt
#
# writing  3p50p0033.txt
#
# writing  3p100p0033.txt
#
# writing  3p200p0033.txt
#
# writing  3p10p0201.txt
#
# writing  3p50p0201.txt
#
# writing  3p100p0201.txt
#
# writing  3p200p0201.txt
#
# writing  3p10p0548.txt
#
# writing  3p50p0548.txt
#
# writing  3p100p0548.txt
#
# writing  3p200p0548.txt
#
# writing  3p10pp08a.txt
#
# writing  3p50pp08a.txt
#
# writing  3p100pp08a.txt
#
# writing  3p200pp08a.txt
#
# writing  3p10pp08aCUTS.txt
#
# writing  3p50pp08aCUTS.txt
#
# writing  3p100pp08aCUTS.txt
#
# writing  3p200pp08aCUTS.txt
#
# writing  3p10qnet1_o.txt
#
# writing  3p50qnet1_o.txt
#
# writing  3p100qnet1_o.txt
#
# writing  3p200qnet1_o.txt
#
# writing  3p10qnet1.txt
#
# writing  3p50qnet1.txt
#
# writing  3p100qnet1.txt
#
# writing  3p200qnet1.txt
#
# writing  3p10rgn.txt
#
# writing  3p50rgn.txt
#
# writing  3p100rgn.txt
#
# writing  3p200rgn.txt
#
# writing  3p10set1ch.txt
#
# writing  3p50set1ch.txt
#
# writing  3p100set1ch.txt
#
# writing  3p200set1ch.txt
#
# writing  3p10stein27.txt
#
# writing  3p50stein27.txt
#
# writing  3p100stein27.txt
#
# writing  3p200stein27.txt
#
# writing  3p10stein45.txt
#
# writing  3p50stein45.txt
#
# writing  3p100stein45.txt
#
# writing  3p200stein45.txt
#
# writing  3p10vpm1.txt
#
# writing  3p50vpm1.txt
#
# writing  3p100vpm1.txt
#
# writing  3p200vpm1.txt
#
# writing  3p10vpm2.txt
#
# writing  3p50vpm2.txt
#
# writing  3p100vpm2.txt
#
# writing  3p200vpm2.txt
#
# writing  4p10air03.txt
#
# writing  4p50air03.txt
#
# writing  4p100air03.txt
#
# writing  4p200air03.txt
#
# writing  4p10bell5.txt
#
# writing  4p50bell5.txt
#
# writing  4p100bell5.txt
#
# writing  4p200bell5.txt
#
# writing  4p10dcmulti.txt
#
# writing  4p50dcmulti.txt
#
# writing  4p100dcmulti.txt
#
# writing  4p200dcmulti.txt
#
# writing  4p10fiber.txt
#
# writing  4p50fiber.txt
#
# writing  4p100fiber.txt
#
# writing  4p200fiber.txt
#
# writing  4p10fixnet6.txt
#
# writing  4p50fixnet6.txt
#
# writing  4p100fixnet6.txt
#
# writing  4p200fixnet6.txt
#
# writing  4p10gen.txt
#
# writing  4p50gen.txt
#
# writing  4p100gen.txt
#
# writing  4p200gen.txt
#
# writing  4p10gesa3.txt
#
# writing  4p50gesa3.txt
#
# writing  4p100gesa3.txt
#
# writing  4p200gesa3.txt
#
# writing  4p10gt2.txt
#
# writing  4p50gt2.txt
#
# writing  4p100gt2.txt
#
# writing  4p200gt2.txt
#
# writing  4p10khb05250.txt
#
# writing  4p50khb05250.txt
#
# writing  4p100khb05250.txt
#
# writing  4p200khb05250.txt
#
# writing  4p10l152lav.txt
#
# writing  4p50l152lav.txt
#
# writing  4p100l152lav.txt
#
# writing  4p200l152lav.txt
#
# writing  4p10misc03.txt
#
# writing  4p50misc03.txt
#
# writing  4p100misc03.txt
#
# writing  4p200misc03.txt
#
# writing  4p10misc06.txt
#
# writing  4p50misc06.txt
#
# writing  4p100misc06.txt
#
# writing  4p200misc06.txt
#
# writing  4p10mod008.txt
#
# writing  4p50mod008.txt
#
# writing  4p100mod008.txt
#
# writing  4p200mod008.txt
#
# writing  4p10mod010.txt
#
# writing  4p50mod010.txt
#
# writing  4p100mod010.txt
#
# writing  4p200mod010.txt
#
# writing  4p10p0033.txt
#
# writing  4p50p0033.txt
#
# writing  4p100p0033.txt
#
# writing  4p200p0033.txt
#
# writing  4p10p0201.txt
#
# writing  4p50p0201.txt
#
# writing  4p100p0201.txt
#
# writing  4p200p0201.txt
#
# writing  4p10p0548.txt
#
# writing  4p50p0548.txt
#
# writing  4p100p0548.txt
#
# writing  4p200p0548.txt
#
# writing  4p10pp08a.txt
#
# writing  4p50pp08a.txt
#
# writing  4p100pp08a.txt
#
# writing  4p200pp08a.txt
#
# writing  4p10pp08aCUTS.txt
#
# writing  4p50pp08aCUTS.txt
#
# writing  4p100pp08aCUTS.txt
#
# writing  4p200pp08aCUTS.txt
#
# writing  4p10qnet1_o.txt
#
# writing  4p50qnet1_o.txt
#
# writing  4p100qnet1_o.txt
#
# writing  4p200qnet1_o.txt
#
# writing  4p10qnet1.txt
#
# writing  4p50qnet1.txt
#
# writing  4p100qnet1.txt
#
# writing  4p200qnet1.txt
#
# writing  4p10rgn.txt
#
# writing  4p50rgn.txt
#
# writing  4p100rgn.txt
#
# writing  4p200rgn.txt
#
# writing  4p10set1ch.txt
#
# writing  4p50set1ch.txt
#
# writing  4p100set1ch.txt
#
# writing  4p200set1ch.txt
#
# writing  4p10stein27.txt
#
# writing  4p50stein27.txt
#
# writing  4p100stein27.txt
#
# writing  4p200stein27.txt
#
# writing  4p10stein45.txt
#
# writing  4p50stein45.txt
#
# writing  4p100stein45.txt
#
# writing  4p200stein45.txt
#
# writing  4p10vpm1.txt
#
# writing  4p50vpm1.txt
#
# writing  4p100vpm1.txt
#
# writing  4p200vpm1.txt
#
# writing  4p10vpm2.txt
#
# writing  4p50vpm2.txt
#
# writing  4p100vpm2.txt
#
# writing  4p200vpm2.txt
#
# writing  5p10air03.txt
#
# writing  5p50air03.txt
#
# writing  5p100air03.txt
#
# writing  5p200air03.txt
#
# writing  5p10bell5.txt
#
# writing  5p50bell5.txt
#
# writing  5p100bell5.txt
#
# writing  5p200bell5.txt
#
# writing  5p10dcmulti.txt
#
# writing  5p50dcmulti.txt
#
# writing  5p100dcmulti.txt
#
# writing  5p200dcmulti.txt
#
# writing  5p10fiber.txt
#
# writing  5p50fiber.txt
#
# writing  5p100fiber.txt
#
# writing  5p200fiber.txt
#
# writing  5p10fixnet6.txt
# writing  5p50fixnet6.txt
#
# writing  5p100fixnet6.txt
#
# writing  5p200fixnet6.txt
#
# writing  5p10gen.txt
#
# writing  5p50gen.txt
#
# writing  5p100gen.txt
#
# writing  5p200gen.txt
#
# writing  5p10gesa3.txt
#
# writing  5p50gesa3.txt
#
# writing  5p100gesa3.txt
#
# writing  5p200gesa3.txt
#
# writing  5p10gt2.txt
#
# writing  5p50gt2.txt
#
# writing  5p100gt2.txt
#
# writing  5p200gt2.txt
#
# writing  5p10khb05250.txt
#
# writing  5p50khb05250.txt
#
# writing  5p100khb05250.txt
#
# writing  5p200khb05250.txt
#
# writing  5p10l152lav.txt
#
# writing  5p50l152lav.txt
#
# writing  5p100l152lav.txt
#
# writing  5p200l152lav.txt
#
# writing  5p10misc03.txt
#
# writing  5p50misc03.txt
#
# writing  5p100misc03.txt
#
# writing  5p200misc03.txt
#
# writing  5p10misc06.txt
#
# writing  5p50misc06.txt
#
# writing  5p100misc06.txt
#
# writing  5p200misc06.txt
#
# writing  5p10mod008.txt
#
# writing  5p50mod008.txt
#
# writing  5p100mod008.txt
#
# writing  5p200mod008.txt
#
# writing  5p10mod010.txt
#
# writing  5p50mod010.txt
#
# writing  5p100mod010.txt
#
# writing  5p200mod010.txt
#
# writing  5p10p0033.txt
#
# writing  5p50p0033.txt
#
# writing  5p100p0033.txt
#
# writing  5p200p0033.txt
#
# writing  5p10p0201.txt
#
# writing  5p50p0201.txt
#
# writing  5p100p0201.txt
#
# writing  5p200p0201.txt
#
# writing  5p10p0548.txt
#
# writing  5p50p0548.txt
#
# writing  5p100p0548.txt
#
# writing  5p200p0548.txt
#
# writing  5p10pp08a.txt
#
# writing  5p50pp08a.txt
#
# writing  5p100pp08a.txt
#
# writing  5p200pp08a.txt
#
# writing  5p10pp08aCUTS.txt
#
# writing  5p50pp08aCUTS.txt
#
# writing  5p100pp08aCUTS.txt
#
# writing  5p200pp08aCUTS.txt
#
# writing  5p10qnet1_o.txt
#
# writing  5p50qnet1_o.txt
#
# writing  5p100qnet1_o.txt
#
# writing  5p200qnet1_o.txt
#
# writing  5p10qnet1.txt
#
# writing  5p50qnet1.txt
#
# writing  5p100qnet1.txt
#
# writing  5p200qnet1.txt
#
# writing  5p10rgn.txt
#
# writing  5p50rgn.txt
#
# writing  5p100rgn.txt
#
# writing  5p200rgn.txt
#
# writing  5p10set1ch.txt
#
# writing  5p50set1ch.txt
#
# writing  5p100set1ch.txt
#
# writing  5p200set1ch.txt
#
# writing  5p10stein27.txt
#
# writing  5p50stein27.txt
#
# writing  5p100stein27.txt
#
# writing  5p200stein27.txt
#
# writing  5p10stein45.txt
#
# writing  5p50stein45.txt
#
# writing  5p100stein45.txt
#
# writing  5p200stein45.txt
#
# writing  5p10vpm1.txt
#
# writing  5p50vpm1.txt
#
# writing  5p100vpm1.txt
#
# writing  5p200vpm1.txt
#
# writing  5p10vpm2.txt
#
# writing  5p50vpm2.txt
#
# writing  5p100vpm2.txt
#
# writing  5p200vpm2.txt
#
# writing  6p10air03.txt
#
# writing  6p50air03.txt
#
# writing  6p100air03.txt
#
# writing  6p200air03.txt
#
# writing  6p10bell5.txt
#
# writing  6p50bell5.txt
#
# writing  6p100bell5.txt
#
# writing  6p200bell5.txt
#
# writing  6p10dcmulti.txt
#
# writing  6p50dcmulti.txt
#
# writing  6p100dcmulti.txt
#
# writing  6p200dcmulti.txt
#
# writing  6p10fiber.txt
#
# writing  6p50fiber.txt
#
# writing  6p100fiber.txt
#
# writing  6p200fiber.txt
#
# writing  6p10fixnet6.txt
#
# writing  6p50fixnet6.txt
#
# writing  6p100fixnet6.txt
#
# writing  6p200fixnet6.txt
#
# writing  6p10gen.txt
#
# writing  6p50gen.txt
#
# writing  6p100gen.txt
#
# writing  6p200gen.txt
#
# writing  6p10gesa3.txt
#
# writing  6p50gesa3.txt
#
# writing  6p100gesa3.txt
#
# writing  6p200gesa3.txt
#
# writing  6p10gt2.txt
#
# writing  6p50gt2.txt
#
# writing  6p100gt2.txt
#
# writing  6p200gt2.txt
#
# writing  6p10khb05250.txt
#
# writing  6p50khb05250.txt
#
# writing  6p100khb05250.txt
#
# writing  6p200khb05250.txt
#
# writing  6p10l152lav.txt
#
# writing  6p50l152lav.txt
#
# writing  6p100l152lav.txt
#
# writing  6p200l152lav.txt
#
# writing  6p10misc03.txt
#
# writing  6p50misc03.txt
#
# writing  6p100misc03.txt
#
# writing  6p200misc03.txt
#
# writing  6p10misc06.txt
#
# writing  6p50misc06.txt
#
# writing  6p100misc06.txt
#
# writing  6p200misc06.txt
#
# writing  6p10mod008.txt
#
# writing  6p50mod008.txt
#
# writing  6p100mod008.txt
#
# writing  6p200mod008.txt
#
# writing  6p10mod010.txt
#
# writing  6p50mod010.txt
#
# writing  6p100mod010.txt
#
# writing  6p200mod010.txt
#
# writing  6p10p0033.txt
#
# writing  6p50p0033.txt
#
# writing  6p100p0033.txt
#
# writing  6p200p0033.txt
#
# writing  6p10p0201.txt
#
# writing  6p50p0201.txt
#
# writing  6p100p0201.txt
#
# writing  6p200p0201.txt
#
# writing  6p10p0548.txt
#
# writing  6p50p0548.txt
#
# writing  6p100p0548.txt
#
# writing  6p200p0548.txt
#
# writing  6p10pp08a.txt
#
# writing  6p50pp08a.txt
#
# writing  6p100pp08a.txt
#
# writing  6p200pp08a.txt
#
# writing  6p10pp08aCUTS.txt
#
# writing  6p50pp08aCUTS.txt
#
# writing  6p100pp08aCUTS.txt
#
# writing  6p200pp08aCUTS.txt
#
# writing  6p10qnet1_o.txt
#
# writing  6p50qnet1_o.txt
#
# writing  6p100qnet1_o.txt
#
# writing  6p200qnet1_o.txt
#
# writing  6p10qnet1.txt
#
# writing  6p50qnet1.txt
#
# writing  6p100qnet1.txt
#
# writing  6p200qnet1.txt
#
# writing  6p10rgn.txt
#
# writing  6p50rgn.txt
#
# writing  6p100rgn.txt
#
# writing  6p200rgn.txt
#
# writing  6p10set1ch.txt
#
# writing  6p50set1ch.txt
#
# writing  6p100set1ch.txt
#
# writing  6p200set1ch.txt
#
# writing  6p10stein27.txt
#
# writing  6p50stein27.txt
#
# writing  6p100stein27.txt
#
# writing  6p200stein27.txt
#
# writing  6p10stein45.txt
#
# writing  6p50stein45.txt
#
# writing  6p100stein45.txt
#
# writing  6p200stein45.txt
#
# writing  6p10vpm1.txt
#
# writing  6p50vpm1.txt
#
# writing  6p100vpm1.txt
#
# writing  6p200vpm1.txt
#
# writing  6p10vpm2.txt
#
# writing  6p50vpm2.txt
#
# writing  6p100vpm2.txt
#
# writing  6p200vpm2.txt
#
# writing  7p10air03.txt
#
# writing  7p50air03.txt
#
# writing  7p100air03.txt
#
# writing  7p200air03.txt
#
# writing  7p10bell5.txt
#
# writing  7p50bell5.txt
#
# writing  7p100bell5.txt
#
# writing  7p200bell5.txt
#
# writing  7p10dcmulti.txt
#
# writing  7p50dcmulti.txt
#
# writing  7p100dcmulti.txt
#
# writing  7p200dcmulti.txt
#
# writing  7p10fiber.txt
#
# writing  7p50fiber.txt
#
# writing  7p100fiber.txt
#
# writing  7p200fiber.txt
#
# writing  7p10fixnet6.txt
#
# writing  7p50fixnet6.txt
#
# writing  7p100fixnet6.txt
#
# writing  7p200fixnet6.txt
#
# writing  7p10gen.txt
#
# writing  7p50gen.txt
#
# writing  7p100gen.txt
#
# writing  7p200gen.txt
#
# writing  7p10gesa3.txt
#
# writing  7p50gesa3.txt
#
# writing  7p100gesa3.txt
#
# writing  7p200gesa3.txt
#
# writing  7p10gt2.txt
#
# writing  7p50gt2.txt
#
# writing  7p100gt2.txt
#
# writing  7p200gt2.txt
#
# writing  7p10khb05250.txt
#
# writing  7p50khb05250.txt
#
# writing  7p100khb05250.txt
#
# writing  7p200khb05250.txt
#
# writing  7p10l152lav.txt
#
# writing  7p50l152lav.txt
#
# writing  7p100l152lav.txt
#
# writing  7p200l152lav.txt
#
# writing  7p10misc03.txt
#
# writing  7p50misc03.txt
#
# writing  7p100misc03.txt
#
# writing  7p200misc03.txt
#
# writing  7p10misc06.txt
#
# writing  7p50misc06.txt
#
# writing  7p100misc06.txt
#
# writing  7p200misc06.txt
#
# writing  7p10mod008.txt
#
# writing  7p50mod008.txt
#
# writing  7p100mod008.txt
#
# writing  7p200mod008.txt
#
# writing  7p10mod010.txt
#
# writing  7p50mod010.txt
#
# writing  7p100mod010.txt
#
# writing  7p200mod010.txt
#
# writing  7p10p0033.txt
#
# writing  7p50p0033.txt
#
# writing  7p100p0033.txt
#
# writing  7p200p0033.txt
#
# writing  7p10p0201.txt
#
# writing  7p50p0201.txt
#
# writing  7p100p0201.txt
#
# writing  7p200p0201.txt
#
# writing  7p10p0548.txt
#
# writing  7p50p0548.txt
#
# writing  7p100p0548.txt
#
# writing  7p200p0548.txt
#
# writing  7p10pp08a.txt
#
# writing  7p50pp08a.txt
#
# writing  7p100pp08a.txt
#
# writing  7p200pp08a.txt
#
# writing  7p10pp08aCUTS.txt
#
# writing  7p50pp08aCUTS.txt
#
# writing  7p100pp08aCUTS.txt
#
# writing  7p200pp08aCUTS.txt
#
# writing  7p10qnet1_o.txt
#
# writing  7p50qnet1_o.txt
#
# writing  7p100qnet1_o.txt
#
# writing  7p200qnet1_o.txt
#
# writing  7p10qnet1.txt
#
# writing  7p50qnet1.txt
#
# writing  7p100qnet1.txt
#
# writing  7p200qnet1.txt
#
# writing  7p10rgn.txt
#
# writing  7p50rgn.txt
#
# writing  7p100rgn.txt
#
# writing  7p200rgn.txt
#
# writing  7p10set1ch.txt
#
# writing  7p50set1ch.txt
#
# writing  7p100set1ch.txt
#
# writing  7p200set1ch.txt
#
# writing  7p10stein27.txt
#
# writing  7p50stein27.txt
#
# writing  7p100stein27.txt
#
# writing  7p200stein27.txt
#
# writing  7p10stein45.txt
#
# writing  7p50stein45.txt
#
# writing  7p100stein45.txt
#
# writing  7p200stein45.txt
#
# writing  7p10vpm1.txt
#
# writing  7p50vpm1.txt
#
# writing  7p100vpm1.txt
#
# writing  7p200vpm1.txt
#
# writing  7p10vpm2.txt
#
# writing  7p50vpm2.txt
#
# writing  7p100vpm2.txt
#
# writing  7p200vpm2.txt
#
# writing  8p10air03.txt
#
# writing  8p50air03.txt
#
# writing  8p100air03.txt
#
# writing  8p200air03.txt
#
# writing  8p10bell5.txt
#
# writing  8p50bell5.txt
#
# writing  8p100bell5.txt
#
# writing  8p200bell5.txt
#
# writing  8p10dcmulti.txt
#
# writing  8p50dcmulti.txt
#
# writing  8p100dcmulti.txt
#
# writing  8p200dcmulti.txt
#
# writing  8p10fiber.txt
#
# writing  8p50fiber.txt
#
# writing  8p100fiber.txt
#
# writing  8p200fiber.txt
#
# writing  8p10fixnet6.txt
#
# writing  8p50fixnet6.txt
#
# writing  8p100fixnet6.txt
#
# writing  8p200fixnet6.txt
#
# writing  8p10gen.txt
#
# writing  8p50gen.txt
#
# writing  8p100gen.txt
#
# writing  8p200gen.txt
#
# writing  8p10gesa3.txt
#
# writing  8p50gesa3.txt
#
# writing  8p100gesa3.txt
#
# writing  8p200gesa3.txt
#
# writing  8p10gt2.txt
#
# writing  8p50gt2.txt
#
# writing  8p100gt2.txt
#
# writing  8p200gt2.txt
#
# writing  8p10khb05250.txt
#
# writing  8p50khb05250.txt
#
# writing  8p100khb05250.txt
#
# writing  8p200khb05250.txt
#
# writing  8p10l152lav.txt
#
# writing  8p50l152lav.txt
#
# writing  8p100l152lav.txt
#
# writing  8p200l152lav.txt
#
# writing  8p10misc03.txt
#
# writing  8p50misc03.txt
#
# writing  8p100misc03.txt
#
# writing  8p200misc03.txt
#
# writing  8p10misc06.txt
#
# writing  8p50misc06.txt
#
# writing  8p100misc06.txt
#
# writing  8p200misc06.txt
#
# writing  8p10mod008.txt
#
# writing  8p50mod008.txt
#
# writing  8p100mod008.txt
#
# writing  8p200mod008.txt
#
# writing  8p10mod010.txt
#
# writing  8p50mod010.txt
#
# writing  8p100mod010.txt
#
# writing  8p200mod010.txt
#
# writing  8p10p0033.txt
#
# writing  8p50p0033.txt
#
# writing  8p100p0033.txt
#
# writing  8p200p0033.txt
#
# writing  8p10p0201.txt
#
# writing  8p50p0201.txt
#
# writing  8p100p0201.txt
#
# writing  8p200p0201.txt
#
# writing  8p10p0548.txt
#
# writing  8p50p0548.txt
#
# writing  8p100p0548.txt
#
# writing  8p200p0548.txt
#
# writing  8p10pp08a.txt
#
# writing  8p50pp08a.txt
#
# writing  8p100pp08a.txt
#
# writing  8p200pp08a.txt
#
# writing  8p10pp08aCUTS.txt
#
# writing  8p50pp08aCUTS.txt
#
# writing  8p100pp08aCUTS.txt
#
# writing  8p200pp08aCUTS.txt
#
# writing  8p10qnet1_o.txt
#
# writing  8p50qnet1_o.txt
#
# writing  8p100qnet1_o.txt
#
# writing  8p200qnet1_o.txt
#
# writing  8p10qnet1.txt
#
# writing  8p50qnet1.txt
#
# writing  8p100qnet1.txt
#
# writing  8p200qnet1.txt
#
# writing  8p10rgn.txt
#
# writing  8p50rgn.txt
#
# writing  8p100rgn.txt
#
# writing  8p200rgn.txt
#
# writing  8p10set1ch.txt
#
# writing  8p50set1ch.txt
#
# writing  8p100set1ch.txt
#
# writing  8p200set1ch.txt
#
# writing  8p10stein27.txt
#
# writing  8p50stein27.txt
#
# writing  8p100stein27.txt
#
# writing  8p200stein27.txt
#
# writing  8p10stein45.txt
#
# writing  8p50stein45.txt
#
# writing  8p100stein45.txt
#
# writing  8p200stein45.txt
#
# writing  8p10vpm1.txt
#
# writing  8p50vpm1.txt
#
# writing  8p100vpm1.txt
#
# writing  8p200vpm1.txt
#
# writing  8p10vpm2.txt
#
# writing  8p50vpm2.txt
#
# writing  8p100vpm2.txt
#
# writing  8p200vpm2.txt
#
# writing  9p10air03.txt
#
# writing  9p50air03.txt
#
# writing  9p100air03.txt
#
# writing  9p200air03.txt
#
# writing  9p10bell5.txt
#
# writing  9p50bell5.txt
#
# writing  9p100bell5.txt
#
# writing  9p200bell5.txt
#
# writing  9p10dcmulti.txt
#
# writing  9p50dcmulti.txt
#
# writing  9p100dcmulti.txt
#
# writing  9p200dcmulti.txt
#
# writing  9p10fiber.txt
#
# writing  9p50fiber.txt
#
# writing  9p100fiber.txt
#
# writing  9p200fiber.txt
#
# writing  9p10fixnet6.txt
#
# writing  9p50fixnet6.txt
#
# writing  9p100fixnet6.txt
#
# writing  9p200fixnet6.txt
#
# writing  9p10gen.txt
#
# writing  9p50gen.txt
#
# writing  9p100gen.txt
#
# writing  9p200gen.txt
# writing  9p10gesa3.txt
#
# writing  9p50gesa3.txt
#
# writing  9p100gesa3.txt
#
# writing  9p200gesa3.txt
#
# writing  9p10gt2.txt
#
# writing  9p50gt2.txt
#
# writing  9p100gt2.txt
#
# writing  9p200gt2.txt
#
# writing  9p10khb05250.txt
#
# writing  9p50khb05250.txt
#
# writing  9p100khb05250.txt
#
# writing  9p200khb05250.txt
#
# writing  9p10l152lav.txt
#
# writing  9p50l152lav.txt
#
# writing  9p100l152lav.txt
#
# writing  9p200l152lav.txt
#
# writing  9p10misc03.txt
#
# writing  9p50misc03.txt
#
# writing  9p100misc03.txt
#
# writing  9p200misc03.txt
#
# writing  9p10misc06.txt
#
# writing  9p50misc06.txt
#
# writing  9p100misc06.txt
#
# writing  9p200misc06.txt
#
# writing  9p10mod008.txt
#
# writing  9p50mod008.txt
#
# writing  9p100mod008.txt
#
# writing  9p200mod008.txt
#
# writing  9p10mod010.txt
#
# writing  9p50mod010.txt
#
# writing  9p100mod010.txt
#
# writing  9p200mod010.txt
#
# writing  9p10p0033.txt
#
# writing  9p50p0033.txt
#
# writing  9p100p0033.txt
#
# writing  9p200p0033.txt
#
# writing  9p10p0201.txt
#
# writing  9p50p0201.txt
#
# writing  9p100p0201.txt
#
# writing  9p200p0201.txt
#
# writing  9p10p0548.txt
#
# writing  9p50p0548.txt
#
# writing  9p100p0548.txt
#
# writing  9p200p0548.txt
#
# writing  9p10pp08a.txt
#
# writing  9p50pp08a.txt
#
# writing  9p100pp08a.txt
#
# writing  9p200pp08a.txt
#
# writing  9p10pp08aCUTS.txt
#
# writing  9p50pp08aCUTS.txt
#
# writing  9p100pp08aCUTS.txt
#
# writing  9p200pp08aCUTS.txt
#
# writing  9p10qnet1_o.txt
#
# writing  9p50qnet1_o.txt
#
# writing  9p100qnet1_o.txt
#
# writing  9p200qnet1_o.txt
#
# writing  9p10qnet1.txt
#
# writing  9p50qnet1.txt
#
# writing  9p100qnet1.txt
#
# writing  9p200qnet1.txt
#
# writing  9p10rgn.txt
#
# writing  9p50rgn.txt
#
# writing  9p100rgn.txt
#
# writing  9p200rgn.txt
#
# writing  9p10set1ch.txt
#
# writing  9p50set1ch.txt
#
# writing  9p100set1ch.txt
#
# writing  9p200set1ch.txt
#
# writing  9p10stein27.txt
#
# writing  9p50stein27.txt
#
# writing  9p100stein27.txt
#
# writing  9p200stein27.txt
#
# writing  9p10stein45.txt
#
# writing  9p50stein45.txt
#
# writing  9p100stein45.txt
#
# writing  9p200stein45.txt
#
# writing  9p10vpm1.txt
#
# writing  9p50vpm1.txt
#
# writing  9p100vpm1.txt
#
# writing  9p200vpm1.txt
#
# writing  9p10vpm2.txt
#
# writing  9p50vpm2.txt
#
# writing  9p100vpm2.txt
#
# writing  9p200vpm2.txt
#
# writing  10p10air03.txt
#
# writing  10p50air03.txt
#
# writing  10p100air03.txt
#
# writing  10p200air03.txt
#
# writing  10p10bell5.txt
#
# writing  10p50bell5.txt
#
# writing  10p100bell5.txt
#
# writing  10p200bell5.txt
#
# writing  10p10dcmulti.txt
#
# writing  10p50dcmulti.txt
#
# writing  10p100dcmulti.txt
#
# writing  10p200dcmulti.txt
#
# writing  10p10fiber.txt
#
# writing  10p50fiber.txt
#
# writing  10p100fiber.txt
#
# writing  10p200fiber.txt
#
# writing  10p10fixnet6.txt
#
# writing  10p50fixnet6.txt
#
# writing  10p100fixnet6.txt
#
# writing  10p200fixnet6.txt
#
# writing  10p10gen.txt
#
# writing  10p50gen.txt
#
# writing  10p100gen.txt
#
# writing  10p200gen.txt
#
# writing  10p10gesa3.txt
#
# writing  10p50gesa3.txt
#
# writing  10p100gesa3.txt
#
# writing  10p200gesa3.txt
#
# writing  10p10gt2.txt
#
# writing  10p50gt2.txt
#
# writing  10p100gt2.txt
#
# writing  10p200gt2.txt
#
# writing  10p10khb05250.txt
#
# writing  10p50khb05250.txt
#
# writing  10p100khb05250.txt
#
# writing  10p200khb05250.txt
#
# writing  10p10l152lav.txt
#
# writing  10p50l152lav.txt
#
# writing  10p100l152lav.txt
#
# writing  10p200l152lav.txt
#
# writing  10p10misc03.txt
#
# writing  10p50misc03.txt
#
# writing  10p100misc03.txt
#
# writing  10p200misc03.txt
#
# writing  10p10misc06.txt
#
# writing  10p50misc06.txt
#
# writing  10p100misc06.txt
#
# writing  10p200misc06.txt
#
# writing  10p10mod008.txt
#
# writing  10p50mod008.txt
#
# writing  10p100mod008.txt
#
# writing  10p200mod008.txt
#
# writing  10p10mod010.txt
#
# writing  10p50mod010.txt
#
# writing  10p100mod010.txt
#
# writing  10p200mod010.txt
#
# writing  10p10p0033.txt
#
# writing  10p50p0033.txt
#
# writing  10p100p0033.txt
#
# writing  10p200p0033.txt
#
# writing  10p10p0201.txt
#
# writing  10p50p0201.txt
#
# writing  10p100p0201.txt
#
# writing  10p200p0201.txt
#
# writing  10p10p0548.txt
#
# writing  10p50p0548.txt
#
# writing  10p100p0548.txt
#
# writing  10p200p0548.txt
#
# writing  10p10pp08a.txt
#
# writing  10p50pp08a.txt
#
# writing  10p100pp08a.txt
#
# writing  10p200pp08a.txt
#
# writing  10p10pp08aCUTS.txt
#
# writing  10p50pp08aCUTS.txt
#
# writing  10p100pp08aCUTS.txt
#
# writing  10p200pp08aCUTS.txt
#
# writing  10p10qnet1_o.txt
#
# writing  10p50qnet1_o.txt
#
# writing  10p100qnet1_o.txt
#
# writing  10p200qnet1_o.txt
#
# writing  10p10qnet1.txt
#
# writing  10p50qnet1.txt
#
# writing  10p100qnet1.txt
#
# writing  10p200qnet1.txt
#
# writing  10p10rgn.txt
#
# writing  10p50rgn.txt
#
# writing  10p100rgn.txt
#
# writing  10p200rgn.txt
#
# writing  10p10set1ch.txt
#
# writing  10p50set1ch.txt
#
# writing  10p100set1ch.txt
#
# writing  10p200set1ch.txt
#
# writing  10p10stein27.txt
#
# writing  10p50stein27.txt
#
# writing  10p100stein27.txt
#
# writing  10p200stein27.txt
#
# writing  10p10stein45.txt
#
# writing  10p50stein45.txt
#
# writing  10p100stein45.txt
#
# writing  10p200stein45.txt
#
# writing  10p10vpm1.txt
#
# writing  10p50vpm1.txt
#
# writing  10p100vpm1.txt
#
# writing  10p200vpm1.txt
#
# writing  10p10vpm2.txt
#
# writing  10p50vpm2.txt
#
# writing  10p100vpm2.txt
#
# writing  10p200vpm2.txt

# %% [markdown]
# ###  ISAAC COMMAND TO SUBMIT ALL JOBS

# %%
cwd = os.getcwd() + '/submitAllJobs'
print(cwd)

allJobsFName = cwd + '/allTrainjobs'

f = open(allJobsFName,'w')
f.write('#!/bin/bash')
f.write('\n')
f.close()

for percent in percentages:
    
    for problem in trainSet:
        
        for j in numNearOptimal:
            
            fName = percent + str(j) + problem
            
            print('writing ',fName)
            with open(allJobsFName,'a') as f:
                f.write('qsub ' + fName)
                f.write('\n')
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/submitAllJobs
# writing  1p10air03
# writing  1p50air03
# writing  1p100air03
# writing  1p200air03
# writing  1p10bell5
# writing  1p50bell5
# writing  1p100bell5
# writing  1p200bell5
# writing  1p10dcmulti
# writing  1p50dcmulti
# writing  1p100dcmulti
# writing  1p200dcmulti
# writing  1p10fiber
# writing  1p50fiber
# writing  1p100fiber
# writing  1p200fiber
# writing  1p10fixnet6
# writing  1p50fixnet6
# writing  1p100fixnet6
# writing  1p200fixnet6
# writing  1p10gen
# writing  1p50gen
# writing  1p100gen
# writing  1p200gen
# writing  1p10gesa3
# writing  1p50gesa3
# writing  1p100gesa3
# writing  1p200gesa3
# writing  1p10gt2
# writing  1p50gt2
# writing  1p100gt2
# writing  1p200gt2
# writing  1p10khb05250
# writing  1p50khb05250
# writing  1p100khb05250
# writing  1p200khb05250
# writing  1p10l152lav
# writing  1p50l152lav
# writing  1p100l152lav
# writing  1p200l152lav
# writing  1p10misc03
# writing  1p50misc03
# writing  1p100misc03
# writing  1p200misc03
# writing  1p10misc06
# writing  1p50misc06
# writing  1p100misc06
# writing  1p200misc06
# writing  1p10mod008
# writing  1p50mod008
# writing  1p100mod008
# writing  1p200mod008
# writing  1p10mod010
# writing  1p50mod010
# writing  1p100mod010
# writing  1p200mod010
# writing  1p10p0033
# writing  1p50p0033
# writing  1p100p0033
# writing  1p200p0033
# writing  1p10p0201
# writing  1p50p0201
# writing  1p100p0201
# writing  1p200p0201
# writing  1p10p0548
# writing  1p50p0548
# writing  1p100p0548
# writing  1p200p0548
# writing  1p10pp08a
# writing  1p50pp08a
# writing  1p100pp08a
# writing  1p200pp08a
# writing  1p10pp08aCUTS
# writing  1p50pp08aCUTS
# writing  1p100pp08aCUTS
# writing  1p200pp08aCUTS
# writing  1p10qnet1_o
# writing  1p50qnet1_o
# writing  1p100qnet1_o
# writing  1p200qnet1_o
# writing  1p10qnet1
# writing  1p50qnet1
# writing  1p100qnet1
# writing  1p200qnet1
# writing  1p10rgn
# writing  1p50rgn
# writing  1p100rgn
# writing  1p200rgn
# writing  1p10set1ch
# writing  1p50set1ch
# writing  1p100set1ch
# writing  1p200set1ch
# writing  1p10stein27
# writing  1p50stein27
# writing  1p100stein27
# writing  1p200stein27
# writing  1p10stein45
# writing  1p50stein45
# writing  1p100stein45
# writing  1p200stein45
# writing  1p10vpm1
# writing  1p50vpm1
# writing  1p100vpm1
# writing  1p200vpm1
# writing  1p10vpm2
# writing  1p50vpm2
# writing  1p100vpm2
# writing  1p200vpm2
# writing  2p10air03
# writing  2p50air03
# writing  2p100air03
# writing  2p200air03
# writing  2p10bell5
# writing  2p50bell5
# writing  2p100bell5
# writing  2p200bell5
# writing  2p10dcmulti
# writing  2p50dcmulti
# writing  2p100dcmulti
# writing  2p200dcmulti
# writing  2p10fiber
# writing  2p50fiber
# writing  2p100fiber
# writing  2p200fiber
# writing  2p10fixnet6
# writing  2p50fixnet6
# writing  2p100fixnet6
# writing  2p200fixnet6
# writing  2p10gen
# writing  2p50gen
# writing  2p100gen
# writing  2p200gen
# writing  2p10gesa3
# writing  2p50gesa3
# writing  2p100gesa3
# writing  2p200gesa3
# writing  2p10gt2
# writing  2p50gt2
# writing  2p100gt2
# writing  2p200gt2
# writing  2p10khb05250
# writing  2p50khb05250
# writing  2p100khb05250
# writing  2p200khb05250
# writing  2p10l152lav
# writing  2p50l152lav
# writing  2p100l152lav
# writing  2p200l152lav
# writing  2p10misc03
# writing  2p50misc03
# writing  2p100misc03
# writing  2p200misc03
# writing  2p10misc06
# writing  2p50misc06
# writing  2p100misc06
# writing  2p200misc06
# writing  2p10mod008
# writing  2p50mod008
# writing  2p100mod008
# writing  2p200mod008
# writing  2p10mod010
# writing  2p50mod010
# writing  2p100mod010
# writing  2p200mod010
# writing  2p10p0033
# writing  2p50p0033
# writing  2p100p0033
# writing  2p200p0033
# writing  2p10p0201
# writing  2p50p0201
# writing  2p100p0201
# writing  2p200p0201
# writing  2p10p0548
# writing  2p50p0548
# writing  2p100p0548
# writing  2p200p0548
# writing  2p10pp08a
# writing  2p50pp08a
# writing  2p100pp08a
# writing  2p200pp08a
# writing  2p10pp08aCUTS
# writing  2p50pp08aCUTS
# writing  2p100pp08aCUTS
# writing  2p200pp08aCUTS
# writing  2p10qnet1_o
# writing  2p50qnet1_o
# writing  2p100qnet1_o
# writing  2p200qnet1_o
# writing  2p10qnet1
# writing  2p50qnet1
# writing  2p100qnet1
# writing  2p200qnet1
# writing  2p10rgn
# writing  2p50rgn
# writing  2p100rgn
# writing  2p200rgn
# writing  2p10set1ch
# writing  2p50set1ch
# writing  2p100set1ch
# writing  2p200set1ch
# writing  2p10stein27
# writing  2p50stein27
# writing  2p100stein27
# writing  2p200stein27
# writing  2p10stein45
# writing  2p50stein45
# writing  2p100stein45
# writing  2p200stein45
# writing  2p10vpm1
# writing  2p50vpm1
# writing  2p100vpm1
# writing  2p200vpm1
# writing  2p10vpm2
# writing  2p50vpm2
# writing  2p100vpm2
# writing  2p200vpm2
# writing  3p10air03
# writing  3p50air03
# writing  3p100air03
# writing  3p200air03
# writing  3p10bell5
# writing  3p50bell5
# writing  3p100bell5
# writing  3p200bell5
# writing  3p10dcmulti
# writing  3p50dcmulti
# writing  3p100dcmulti
# writing  3p200dcmulti
# writing  3p10fiber
# writing  3p50fiber
# writing  3p100fiber
# writing  3p200fiber
# writing  3p10fixnet6
# writing  3p50fixnet6
# writing  3p100fixnet6
# writing  3p200fixnet6
# writing  3p10gen
# writing  3p50gen
# writing  3p100gen
# writing  3p200gen
# writing  3p10gesa3
# writing  3p50gesa3
# writing  3p100gesa3
# writing  3p200gesa3
# writing  3p10gt2
# writing  3p50gt2
# writing  3p100gt2
# writing  3p200gt2
# writing  3p10khb05250
# writing  3p50khb05250
# writing  3p100khb05250
# writing  3p200khb05250
# writing  3p10l152lav
# writing  3p50l152lav
# writing  3p100l152lav
# writing  3p200l152lav
# writing  3p10misc03
# writing  3p50misc03
# writing  3p100misc03
# writing  3p200misc03
# writing  3p10misc06
# writing  3p50misc06
# writing  3p100misc06
# writing  3p200misc06
# writing  3p10mod008
# writing  3p50mod008
# writing  3p100mod008
# writing  3p200mod008
# writing  3p10mod010
# writing  3p50mod010
# writing  3p100mod010
# writing  3p200mod010
# writing  3p10p0033
# writing  3p50p0033
# writing  3p100p0033
# writing  3p200p0033
# writing  3p10p0201
# writing  3p50p0201
# writing  3p100p0201
# writing  3p200p0201
# writing  3p10p0548
# writing  3p50p0548
# writing  3p100p0548
# writing  3p200p0548
# writing  3p10pp08a
# writing  3p50pp08a
# writing  3p100pp08a
# writing  3p200pp08a
# writing  3p10pp08aCUTS
# writing  3p50pp08aCUTS
# writing  3p100pp08aCUTS
# writing  3p200pp08aCUTS
# writing  3p10qnet1_o
# writing  3p50qnet1_o
# writing  3p100qnet1_o
# writing  3p200qnet1_o
# writing  3p10qnet1
# writing  3p50qnet1
# writing  3p100qnet1
# writing  3p200qnet1
# writing  3p10rgn
# writing  3p50rgn
# writing  3p100rgn
# writing  3p200rgn
# writing  3p10set1ch
# writing  3p50set1ch
# writing  3p100set1ch
# writing  3p200set1ch
# writing  3p10stein27
# writing  3p50stein27
# writing  3p100stein27
# writing  3p200stein27
# writing  3p10stein45
# writing  3p50stein45
# writing  3p100stein45
# writing  3p200stein45
# writing  3p10vpm1
# writing  3p50vpm1
# writing  3p100vpm1
# writing  3p200vpm1
# writing  3p10vpm2
# writing  3p50vpm2
# writing  3p100vpm2
# writing  3p200vpm2
# writing  4p10air03
# writing  4p50air03
# writing  4p100air03
# writing  4p200air03
# writing  4p10bell5
# writing  4p50bell5
# writing  4p100bell5
# writing  4p200bell5
# writing  4p10dcmulti
# writing  4p50dcmulti
# writing  4p100dcmulti
# writing  4p200dcmulti
# writing  4p10fiber
# writing  4p50fiber
# writing  4p100fiber
# writing  4p200fiber
# writing  4p10fixnet6
# writing  4p50fixnet6
# writing  4p100fixnet6
# writing  4p200fixnet6
# writing  4p10gen
# writing  4p50gen
# writing  4p100gen
# writing  4p200gen
# writing  4p10gesa3
# writing  4p50gesa3
# writing  4p100gesa3
# writing  4p200gesa3
# writing  4p10gt2
# writing  4p50gt2
# writing  4p100gt2
# writing  4p200gt2
# writing  4p10khb05250
# writing  4p50khb05250
# writing  4p100khb05250
# writing  4p200khb05250
# writing  4p10l152lav
# writing  4p50l152lav
# writing  4p100l152lav
# writing  4p200l152lav
# writing  4p10misc03
# writing  4p50misc03
# writing  4p100misc03
# writing  4p200misc03
# writing  4p10misc06
# writing  4p50misc06
# writing  4p100misc06
# writing  4p200misc06
# writing  4p10mod008
# writing  4p50mod008
# writing  4p100mod008
# writing  4p200mod008
# writing  4p10mod010
# writing  4p50mod010
# writing  4p100mod010
# writing  4p200mod010
# writing  4p10p0033
# writing  4p50p0033
# writing  4p100p0033
# writing  4p200p0033
# writing  4p10p0201
# writing  4p50p0201
# writing  4p100p0201
# writing  4p200p0201
# writing  4p10p0548
# writing  4p50p0548
# writing  4p100p0548
# writing  4p200p0548
# writing  4p10pp08a
# writing  4p50pp08a
# writing  4p100pp08a
# writing  4p200pp08a
# writing  4p10pp08aCUTS
# writing  4p50pp08aCUTS
# writing  4p100pp08aCUTS
# writing  4p200pp08aCUTS
# writing  4p10qnet1_o
# writing  4p50qnet1_o
# writing  4p100qnet1_o
# writing  4p200qnet1_o
# writing  4p10qnet1
# writing  4p50qnet1
# writing  4p100qnet1
# writing  4p200qnet1
# writing  4p10rgn
# writing  4p50rgn
# writing  4p100rgn
# writing  4p200rgn
# writing  4p10set1ch
# writing  4p50set1ch
# writing  4p100set1ch
# writing  4p200set1ch
# writing  4p10stein27
# writing  4p50stein27
# writing  4p100stein27
# writing  4p200stein27
# writing  4p10stein45
# writing  4p50stein45
# writing  4p100stein45
# writing  4p200stein45
# writing  4p10vpm1
# writing  4p50vpm1
# writing  4p100vpm1
# writing  4p200vpm1
# writing  4p10vpm2
# writing  4p50vpm2
# writing  4p100vpm2
# writing  4p200vpm2
# writing  5p10air03
# writing  5p50air03
# writing  5p100air03
# writing  5p200air03
# writing  5p10bell5
# writing  5p50bell5
# writing  5p100bell5
# writing  5p200bell5
# writing  5p10dcmulti
# writing  5p50dcmulti
# writing  5p100dcmulti
# writing  5p200dcmulti
# writing  5p10fiber
# writing  5p50fiber
# writing  5p100fiber
# writing  5p200fiber
# writing  5p10fixnet6
# writing  5p50fixnet6
# writing  5p100fixnet6
# writing  5p200fixnet6
# writing  5p10gen
# writing  5p50gen
# writing  5p100gen
# writing  5p200gen
# writing  5p10gesa3
# writing  5p50gesa3
# writing  5p100gesa3
# writing  5p200gesa3
# writing  5p10gt2
# writing  5p50gt2
# writing  5p100gt2
# writing  5p200gt2
# writing  5p10khb05250
# writing  5p50khb05250
# writing  5p100khb05250
# writing  5p200khb05250
# writing  5p10l152lav
# writing  5p50l152lav
# writing  5p100l152lav
# writing  5p200l152lav
# writing  5p10misc03
# writing  5p50misc03
# writing  5p100misc03
# writing  5p200misc03
# writing  5p10misc06
# writing  5p50misc06
# writing  5p100misc06
# writing  5p200misc06
# writing  5p10mod008
# writing  5p50mod008
# writing  5p100mod008
# writing  5p200mod008
# writing  5p10mod010
# writing  5p50mod010
# writing  5p100mod010
# writing  5p200mod010
# writing  5p10p0033
# writing  5p50p0033
# writing  5p100p0033
# writing  5p200p0033
# writing  5p10p0201
# writing  5p50p0201
# writing  5p100p0201
# writing  5p200p0201
# writing  5p10p0548
# writing  5p50p0548
# writing  5p100p0548
# writing  5p200p0548
# writing  5p10pp08a
# writing  5p50pp08a
# writing  5p100pp08a
# writing  5p200pp08a
# writing  5p10pp08aCUTS
# writing  5p50pp08aCUTS
# writing  5p100pp08aCUTS
# writing  5p200pp08aCUTS
# writing  5p10qnet1_o
# writing  5p50qnet1_o
# writing  5p100qnet1_o
# writing  5p200qnet1_o
# writing  5p10qnet1
# writing  5p50qnet1
# writing  5p100qnet1
# writing  5p200qnet1
# writing  5p10rgn
# writing  5p50rgn
# writing  5p100rgn
# writing  5p200rgn
# writing  5p10set1ch
# writing  5p50set1ch
# writing  5p100set1ch
# writing  5p200set1ch
# writing  5p10stein27
# writing  5p50stein27
# writing  5p100stein27
# writing  5p200stein27
# writing  5p10stein45
# writing  5p50stein45
# writing  5p100stein45
# writing  5p200stein45
# writing  5p10vpm1
# writing  5p50vpm1
# writing  5p100vpm1
# writing  5p200vpm1
# writing  5p10vpm2
# writing  5p50vpm2
# writing  5p100vpm2
# writing  5p200vpm2
# writing  6p10air03
# writing  6p50air03
# writing  6p100air03
# writing  6p200air03
# writing  6p10bell5
# writing  6p50bell5
# writing  6p100bell5
# writing  6p200bell5
# writing  6p10dcmulti
# writing  6p50dcmulti
# writing  6p100dcmulti
# writing  6p200dcmulti
# writing  6p10fiber
# writing  6p50fiber
# writing  6p100fiber
# writing  6p200fiber
# writing  6p10fixnet6
# writing  6p50fixnet6
# writing  6p100fixnet6
# writing  6p200fixnet6
# writing  6p10gen
# writing  6p50gen
# writing  6p100gen
# writing  6p200gen
# writing  6p10gesa3
# writing  6p50gesa3
# writing  6p100gesa3
# writing  6p200gesa3
# writing  6p10gt2
# writing  6p50gt2
# writing  6p100gt2
# writing  6p200gt2
# writing  6p10khb05250
# writing  6p50khb05250
# writing  6p100khb05250
# writing  6p200khb05250
# writing  6p10l152lav
# writing  6p50l152lav
# writing  6p100l152lav
# writing  6p200l152lav
# writing  6p10misc03
# writing  6p50misc03
# writing  6p100misc03
# writing  6p200misc03
# writing  6p10misc06
# writing  6p50misc06
# writing  6p100misc06
# writing  6p200misc06
# writing  6p10mod008
# writing  6p50mod008
# writing  6p100mod008
# writing  6p200mod008
# writing  6p10mod010
# writing  6p50mod010
# writing  6p100mod010
# writing  6p200mod010
# writing  6p10p0033
# writing  6p50p0033
# writing  6p100p0033
# writing  6p200p0033
# writing  6p10p0201
# writing  6p50p0201
# writing  6p100p0201
# writing  6p200p0201
# writing  6p10p0548
# writing  6p50p0548
# writing  6p100p0548
# writing  6p200p0548
# writing  6p10pp08a
# writing  6p50pp08a
# writing  6p100pp08a
# writing  6p200pp08a
# writing  6p10pp08aCUTS
# writing  6p50pp08aCUTS
# writing  6p100pp08aCUTS
# writing  6p200pp08aCUTS
# writing  6p10qnet1_o
# writing  6p50qnet1_o
# writing  6p100qnet1_o
# writing  6p200qnet1_o
# writing  6p10qnet1
# writing  6p50qnet1
# writing  6p100qnet1
# writing  6p200qnet1
# writing  6p10rgn
# writing  6p50rgn
# writing  6p100rgn
# writing  6p200rgn
# writing  6p10set1ch
# writing  6p50set1ch
# writing  6p100set1ch
# writing  6p200set1ch
# writing  6p10stein27
# writing  6p50stein27
# writing  6p100stein27
# writing  6p200stein27
# writing  6p10stein45
# writing  6p50stein45
# writing  6p100stein45
# writing  6p200stein45
# writing  6p10vpm1
# writing  6p50vpm1
# writing  6p100vpm1
# writing  6p200vpm1
# writing  6p10vpm2
# writing  6p50vpm2
# writing  6p100vpm2
# writing  6p200vpm2
# writing  7p10air03
# writing  7p50air03
# writing  7p100air03
# writing  7p200air03
# writing  7p10bell5
# writing  7p50bell5
# writing  7p100bell5
# writing  7p200bell5
# writing  7p10dcmulti
# writing  7p50dcmulti
# writing  7p100dcmulti
# writing  7p200dcmulti
# writing  7p10fiber
# writing  7p50fiber
# writing  7p100fiber
# writing  7p200fiber
# writing  7p10fixnet6
# writing  7p50fixnet6
# writing  7p100fixnet6
# writing  7p200fixnet6
# writing  7p10gen
# writing  7p50gen
# writing  7p100gen
# writing  7p200gen
# writing  7p10gesa3
# writing  7p50gesa3
# writing  7p100gesa3
# writing  7p200gesa3
# writing  7p10gt2
# writing  7p50gt2
# writing  7p100gt2
# writing  7p200gt2
# writing  7p10khb05250
# writing  7p50khb05250
# writing  7p100khb05250
# writing  7p200khb05250
# writing  7p10l152lav
# writing  7p50l152lav
# writing  7p100l152lav
# writing  7p200l152lav
# writing  7p10misc03
# writing  7p50misc03
# writing  7p100misc03
# writing  7p200misc03
# writing  7p10misc06
# writing  7p50misc06
# writing  7p100misc06
# writing  7p200misc06
# writing  7p10mod008
# writing  7p50mod008
# writing  7p100mod008
# writing  7p200mod008
# writing  7p10mod010
# writing  7p50mod010
# writing  7p100mod010
# writing  7p200mod010
# writing  7p10p0033
# writing  7p50p0033
# writing  7p100p0033
# writing  7p200p0033
# writing  7p10p0201
# writing  7p50p0201
# writing  7p100p0201
# writing  7p200p0201
# writing  7p10p0548
# writing  7p50p0548
# writing  7p100p0548
# writing  7p200p0548
# writing  7p10pp08a
# writing  7p50pp08a
# writing  7p100pp08a
# writing  7p200pp08a
# writing  7p10pp08aCUTS
# writing  7p50pp08aCUTS
# writing  7p100pp08aCUTS
# writing  7p200pp08aCUTS
# writing  7p10qnet1_o
# writing  7p50qnet1_o
# writing  7p100qnet1_o
# writing  7p200qnet1_o
# writing  7p10qnet1
# writing  7p50qnet1
# writing  7p100qnet1
# writing  7p200qnet1
# writing  7p10rgn
# writing  7p50rgn
# writing  7p100rgn
# writing  7p200rgn
# writing  7p10set1ch
# writing  7p50set1ch
# writing  7p100set1ch
# writing  7p200set1ch
# writing  7p10stein27
# writing  7p50stein27
# writing  7p100stein27
# writing  7p200stein27
# writing  7p10stein45
# writing  7p50stein45
# writing  7p100stein45
# writing  7p200stein45
# writing  7p10vpm1
# writing  7p50vpm1
# writing  7p100vpm1
# writing  7p200vpm1
# writing  7p10vpm2
# writing  7p50vpm2
# writing  7p100vpm2
# writing  7p200vpm2
# writing  8p10air03
# writing  8p50air03
# writing  8p100air03
# writing  8p200air03
# writing  8p10bell5
# writing  8p50bell5
# writing  8p100bell5
# writing  8p200bell5
# writing  8p10dcmulti
# writing  8p50dcmulti
# writing  8p100dcmulti
# writing  8p200dcmulti
# writing  8p10fiber
# writing  8p50fiber
# writing  8p100fiber
# writing  8p200fiber
# writing  8p10fixnet6
# writing  8p50fixnet6
# writing  8p100fixnet6
# writing  8p200fixnet6
# writing  8p10gen
# writing  8p50gen
# writing  8p100gen
# writing  8p200gen
# writing  8p10gesa3
# writing  8p50gesa3
# writing  8p100gesa3
# writing  8p200gesa3
# writing  8p10gt2
# writing  8p50gt2
# writing  8p100gt2
# writing  8p200gt2
# writing  8p10khb05250
# writing  8p50khb05250
# writing  8p100khb05250
# writing  8p200khb05250
# writing  8p10l152lav
# writing  8p50l152lav
# writing  8p100l152lav
# writing  8p200l152lav
# writing  8p10misc03
# writing  8p50misc03
# writing  8p100misc03
# writing  8p200misc03
# writing  8p10misc06
# writing  8p50misc06
# writing  8p100misc06
# writing  8p200misc06
# writing  8p10mod008
# writing  8p50mod008
# writing  8p100mod008
# writing  8p200mod008
# writing  8p10mod010
# writing  8p50mod010
# writing  8p100mod010
# writing  8p200mod010
# writing  8p10p0033
# writing  8p50p0033
# writing  8p100p0033
# writing  8p200p0033
# writing  8p10p0201
# writing  8p50p0201
# writing  8p100p0201
# writing  8p200p0201
# writing  8p10p0548
# writing  8p50p0548
# writing  8p100p0548
# writing  8p200p0548
# writing  8p10pp08a
# writing  8p50pp08a
# writing  8p100pp08a
# writing  8p200pp08a
# writing  8p10pp08aCUTS
# writing  8p50pp08aCUTS
# writing  8p100pp08aCUTS
# writing  8p200pp08aCUTS
# writing  8p10qnet1_o
# writing  8p50qnet1_o
# writing  8p100qnet1_o
# writing  8p200qnet1_o
# writing  8p10qnet1
# writing  8p50qnet1
# writing  8p100qnet1
# writing  8p200qnet1
# writing  8p10rgn
# writing  8p50rgn
# writing  8p100rgn
# writing  8p200rgn
# writing  8p10set1ch
# writing  8p50set1ch
# writing  8p100set1ch
# writing  8p200set1ch
# writing  8p10stein27
# writing  8p50stein27
# writing  8p100stein27
# writing  8p200stein27
# writing  8p10stein45
# writing  8p50stein45
# writing  8p100stein45
# writing  8p200stein45
# writing  8p10vpm1
# writing  8p50vpm1
# writing  8p100vpm1
# writing  8p200vpm1
# writing  8p10vpm2
# writing  8p50vpm2
# writing  8p100vpm2
# writing  8p200vpm2
# writing  9p10air03
# writing  9p50air03
# writing  9p100air03
# writing  9p200air03
# writing  9p10bell5
# writing  9p50bell5
# writing  9p100bell5
# writing  9p200bell5
# writing  9p10dcmulti
# writing  9p50dcmulti
# writing  9p100dcmulti
# writing  9p200dcmulti
# writing  9p10fiber
# writing  9p50fiber
# writing  9p100fiber
# writing  9p200fiber
# writing  9p10fixnet6
# writing  9p50fixnet6
# writing  9p100fixnet6
# writing  9p200fixnet6
# writing  9p10gen
# writing  9p50gen
# writing  9p100gen
# writing  9p200gen
# writing  9p10gesa3
# writing  9p50gesa3
# writing  9p100gesa3
# writing  9p200gesa3
# writing  9p10gt2
# writing  9p50gt2
# writing  9p100gt2
# writing  9p200gt2
# writing  9p10khb05250
# writing  9p50khb05250
# writing  9p100khb05250
# writing  9p200khb05250
# writing  9p10l152lav
# writing  9p50l152lav
# writing  9p100l152lav
# writing  9p200l152lav
# writing  9p10misc03
# writing  9p50misc03
# writing  9p100misc03
# writing  9p200misc03
# writing  9p10misc06
# writing  9p50misc06
# writing  9p100misc06
# writing  9p200misc06
# writing  9p10mod008
# writing  9p50mod008
# writing  9p100mod008
# writing  9p200mod008
# writing  9p10mod010
# writing  9p50mod010
# writing  9p100mod010
# writing  9p200mod010
# writing  9p10p0033
# writing  9p50p0033
# writing  9p100p0033
# writing  9p200p0033
# writing  9p10p0201
# writing  9p50p0201
# writing  9p100p0201
# writing  9p200p0201
# writing  9p10p0548
# writing  9p50p0548
# writing  9p100p0548
# writing  9p200p0548
# writing  9p10pp08a
# writing  9p50pp08a
# writing  9p100pp08a
# writing  9p200pp08a
# writing  9p10pp08aCUTS
# writing  9p50pp08aCUTS
# writing  9p100pp08aCUTS
# writing  9p200pp08aCUTS
# writing  9p10qnet1_o
# writing  9p50qnet1_o
# writing  9p100qnet1_o
# writing  9p200qnet1_o
# writing  9p10qnet1
# writing  9p50qnet1
# writing  9p100qnet1
# writing  9p200qnet1
# writing  9p10rgn
# writing  9p50rgn
# writing  9p100rgn
# writing  9p200rgn
# writing  9p10set1ch
# writing  9p50set1ch
# writing  9p100set1ch
# writing  9p200set1ch
# writing  9p10stein27
# writing  9p50stein27
# writing  9p100stein27
# writing  9p200stein27
# writing  9p10stein45
# writing  9p50stein45
# writing  9p100stein45
# writing  9p200stein45
# writing  9p10vpm1
# writing  9p50vpm1
# writing  9p100vpm1
# writing  9p200vpm1
# writing  9p10vpm2
# writing  9p50vpm2
# writing  9p100vpm2
# writing  9p200vpm2
# writing  10p10air03
# writing  10p50air03
# writing  10p100air03
# writing  10p200air03
# writing  10p10bell5
# writing  10p50bell5
# writing  10p100bell5
# writing  10p200bell5
# writing  10p10dcmulti
# writing  10p50dcmulti
# writing  10p100dcmulti
# writing  10p200dcmulti
# writing  10p10fiber
# writing  10p50fiber
# writing  10p100fiber
# writing  10p200fiber
# writing  10p10fixnet6
# writing  10p50fixnet6
# writing  10p100fixnet6
# writing  10p200fixnet6
# writing  10p10gen
# writing  10p50gen
# writing  10p100gen
# writing  10p200gen
# writing  10p10gesa3
# writing  10p50gesa3
# writing  10p100gesa3
# writing  10p200gesa3
# writing  10p10gt2
# writing  10p50gt2
# writing  10p100gt2
# writing  10p200gt2
# writing  10p10khb05250
# writing  10p50khb05250
# writing  10p100khb05250
# writing  10p200khb05250
# writing  10p10l152lav
# writing  10p50l152lav
# writing  10p100l152lav
# writing  10p200l152lav
# writing  10p10misc03
# writing  10p50misc03
# writing  10p100misc03
# writing  10p200misc03
# writing  10p10misc06
# writing  10p50misc06
# writing  10p100misc06
# writing  10p200misc06
# writing  10p10mod008
# writing  10p50mod008
# writing  10p100mod008
# writing  10p200mod008
# writing  10p10mod010
# writing  10p50mod010
# writing  10p100mod010
# writing  10p200mod010
# writing  10p10p0033
# writing  10p50p0033
# writing  10p100p0033
# writing  10p200p0033
# writing  10p10p0201
# writing  10p50p0201
# writing  10p100p0201
# writing  10p200p0201
# writing  10p10p0548
# writing  10p50p0548
# writing  10p100p0548
# writing  10p200p0548
# writing  10p10pp08a
# writing  10p50pp08a
# writing  10p100pp08a
# writing  10p200pp08a
# writing  10p10pp08aCUTS
# writing  10p50pp08aCUTS
# writing  10p100pp08aCUTS
# writing  10p200pp08aCUTS
# writing  10p10qnet1_o
# writing  10p50qnet1_o
# writing  10p100qnet1_o
# writing  10p200qnet1_o
# writing  10p10qnet1
# writing  10p50qnet1
# writing  10p100qnet1
# writing  10p200qnet1
# writing  10p10rgn
# writing  10p50rgn
# writing  10p100rgn
# writing  10p200rgn
# writing  10p10set1ch
# writing  10p50set1ch
# writing  10p100set1ch
# writing  10p200set1ch
# writing  10p10stein27
# writing  10p50stein27
# writing  10p100stein27
# writing  10p200stein27
# writing  10p10stein45
# writing  10p50stein45
# writing  10p100stein45
# writing  10p200stein45
# writing  10p10vpm1
# writing  10p50vpm1
# writing  10p100vpm1
# writing  10p200vpm1
# writing  10p10vpm2
# writing  10p50vpm2
# writing  10p100vpm2
# writing  10p200vpm2

# %% [markdown]
# ### TESTSET PROBLEMS

# %%
testSet = ['23588','bppc8-02','exp-1-500-5-5','mtest4ma','neos-1425699','neos17','nexp-50-20-1-1','sp150x300d','nexp-50-20-4-2']

# %%
testSet
# Out:
# ['23588',
#  'bppc8-02',
#  'exp-1-500-5-5',
#  'mtest4ma',
#  'neos-1425699',
#  'neos17',
#  'nexp-50-20-1-1',
#  'sp150x300d',
#  'nexp-50-20-4-2']

# %%
percentNearOptimal = {'1p':0.01,'2p':0.02,'3p':0.03,'4p':0.04,'5p':0.05,'6p':0.06,'7p':0.07,'8p':0.08,'9p':0.09,'10p':0.10}

# %%
numNearOptimal = [10,50,100,200,1000]

# %%
percentages = ['1p','2p','3p','4p','5p','6p','7p','8p','9p','10p']

# %% [markdown]
# #### RUN FILES

# %%
cwd = os.getcwd() + '/Test'
print(cwd)

for percent in percentages:
    
    for problem in testSet:
        
        for j in numNearOptimal:
            
            fName = percent + str(j) + problem
            testFileName = percent + str(j) + problem + '.txt'
            fullFName = cwd  +'/' + fName
            
            print('writing ',fName, '\n')
            with open(fullFName,'w') as f:
                f.write('#!/bin/bash')
                f.write('\n')
                f.write('#')
                f.write('\n')
                f.write('#PBS -N ' + percent + fName)
                f.write('\n')
                f.write('#PBS -M iahanor@vols.utk.edu')
                f.write('\n')
                f.write('#PBS -m abe')
                f.write('\n')
                f.write('#PBS -A ACF-UTK0011')
                f.write('\n')
                f.write('#PBS -o /lustre/haven/user/iahanor/branchandbound/Test/' +  percent + '/' + fName + 'O.txt')
                f.write('\n')
                f.write('#PBS -e /lustre/haven/user/iahanor/branchandbound/Test/' + percent + '/' + fName + 'E.txt')
                f.write('\n')
                f.write('#PBS -l walltime=24:00:00')
                f.write('\n')
                f.write('#PBS -l nodes=1:ppn=4')
                f.write('\n')
                f.write('#PBS -l partition=gpu')
                f.write('\n')
                f.write('#PBS -l feature=cascadelake_gpu')
                f.write('\n')
                f.write('\n')
                f.write('cd /lustre/haven/user/iahanor/branchandbound/Test/' + percent)
                f.write('\n')
                f.write('mkdir ' + fName + 'F')
                f.write('\n')
                f.write('cd ' + fName + 'F')
                f.write('\n')
                f.write('\n')
                f.write('git clone https://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@github.com/izuwaa/Diversitree.git')
                f.write('\n')
                f.write('cd Diversitree')
                f.write('\n')
                f.write('module load gcc/6.3.0')
                f.write('\n')
                f.write('module load cmake')
                f.write('\n')
                f.write('\n')
                f.write('cmake -Bbuild -H. -DSCIP_DIR=/lustre/haven/user/iahanor/branchandbound/scipoptsuite-7.0.3/installDir/lib/cmake/scip -DGMP_INCLUDE_DIR=/sw/cs400_centos7.3_acfsoftware/gmp/5.1.1/centos7.3_intel17.2.174/include')
                f.write('\n')
                f.write('cmake --build build')
                f.write('\n')
                f.write('echo "module loaded"')
                f.write('\n')
                f.write('\n')
                f.write('cd /lustre/haven/user/iahanor/branchandbound/Test/' + percent + '/' + fName + 'F' + '/' + 'Diversitree')
                f.write('\n')
                f.write('/lustre/haven/user/iahanor/branchandbound/Test/' + percent + '/' + fName + 'F' + '/' + 'Diversitree/build/diversitree ' + testFileName + ' problemOptions , solverParams.txt solverOptions :')
                f.write('\n')
                f.write('echo "module I am done"')
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/Test
# writing  1p1023588
#
# writing  1p5023588
#
# writing  1p10023588
#
# writing  1p20023588
#
# writing  1p100023588
#
# writing  1p10bppc8-02
#
# writing  1p50bppc8-02
#
# writing  1p100bppc8-02
#
# writing  1p200bppc8-02
#
# writing  1p1000bppc8-02
#
# writing  1p10exp-1-500-5-5
#
# writing  1p50exp-1-500-5-5
#
# writing  1p100exp-1-500-5-5
#
# writing  1p200exp-1-500-5-5
#
# writing  1p1000exp-1-500-5-5
#
# writing  1p10mtest4ma
#
# writing  1p50mtest4ma
#
# writing  1p100mtest4ma
#
# writing  1p200mtest4ma
#
# writing  1p1000mtest4ma
#
# writing  1p10neos-1425699
#
# writing  1p50neos-1425699
#
# writing  1p100neos-1425699
#
# writing  1p200neos-1425699
#
# writing  1p1000neos-1425699
#
# writing  1p10neos17
#
# writing  1p50neos17
#
# writing  1p100neos17
#
# writing  1p200neos17
#
# writing  1p1000neos17
#
# writing  1p10nexp-50-20-1-1
#
# writing  1p50nexp-50-20-1-1
#
# writing  1p100nexp-50-20-1-1
#
# writing  1p200nexp-50-20-1-1
#
# writing  1p1000nexp-50-20-1-1
#
# writing  1p10sp150x300d
#
# writing  1p50sp150x300d
#
# writing  1p100sp150x300d
#
# writing  1p200sp150x300d
#
# writing  1p1000sp150x300d
#
# writing  1p10nexp-50-20-4-2
#
# writing  1p50nexp-50-20-4-2
#
# writing  1p100nexp-50-20-4-2
#
# writing  1p200nexp-50-20-4-2
#
# writing  1p1000nexp-50-20-4-2
#
# writing  2p1023588
#
# writing  2p5023588
#
# writing  2p10023588
#
# writing  2p20023588
#
# writing  2p100023588
#
# writing  2p10bppc8-02
#
# writing  2p50bppc8-02
#
# writing  2p100bppc8-02
#
# writing  2p200bppc8-02
#
# writing  2p1000bppc8-02
#
# writing  2p10exp-1-500-5-5
#
# writing  2p50exp-1-500-5-5
#
# writing  2p100exp-1-500-5-5
#
# writing  2p200exp-1-500-5-5
#
# writing  2p1000exp-1-500-5-5
#
# writing  2p10mtest4ma
#
# writing  2p50mtest4ma
#
# writing  2p100mtest4ma
#
# writing  2p200mtest4ma
#
# writing  2p1000mtest4ma
#
# writing  2p10neos-1425699
#
# writing  2p50neos-1425699
#
# writing  2p100neos-1425699
#
# writing  2p200neos-1425699
#
# writing  2p1000neos-1425699
#
# writing  2p10neos17
#
# writing  2p50neos17
#
# writing  2p100neos17
#
# writing  2p200neos17
#
# writing  2p1000neos17
#
# writing  2p10nexp-50-20-1-1
#
# writing  2p50nexp-50-20-1-1
#
# writing  2p100nexp-50-20-1-1
#
# writing  2p200nexp-50-20-1-1
#
# writing  2p1000nexp-50-20-1-1
#
# writing  2p10sp150x300d
#
# writing  2p50sp150x300d
#
# writing  2p100sp150x300d
#
# writing  2p200sp150x300d
#
# writing  2p1000sp150x300d
#
# writing  2p10nexp-50-20-4-2
#
# writing  2p50nexp-50-20-4-2
#
# writing  2p100nexp-50-20-4-2
#
# writing  2p200nexp-50-20-4-2
#
# writing  2p1000nexp-50-20-4-2
#
# writing  3p1023588
#
# writing  3p5023588
#
# writing  3p10023588
#
# writing  3p20023588
#
# writing  3p100023588
#
# writing  3p10bppc8-02
#
# writing  3p50bppc8-02
#
# writing  3p100bppc8-02
#
# writing  3p200bppc8-02
#
# writing  3p1000bppc8-02
#
# writing  3p10exp-1-500-5-5
#
# writing  3p50exp-1-500-5-5
#
# writing  3p100exp-1-500-5-5
#
# writing  3p200exp-1-500-5-5
#
# writing  3p1000exp-1-500-5-5
#
# writing  3p10mtest4ma
#
# writing  3p50mtest4ma
#
# writing  3p100mtest4ma
#
# writing  3p200mtest4ma
#
# writing  3p1000mtest4ma
#
# writing  3p10neos-1425699
#
# writing  3p50neos-1425699
#
# writing  3p100neos-1425699
#
# writing  3p200neos-1425699
#
# writing  3p1000neos-1425699
#
# writing  3p10neos17
#
# writing  3p50neos17
#
# writing  3p100neos17
#
# writing  3p200neos17
#
# writing  3p1000neos17
#
# writing  3p10nexp-50-20-1-1
#
# writing  3p50nexp-50-20-1-1
#
# writing  3p100nexp-50-20-1-1
#
# writing  3p200nexp-50-20-1-1
#
# writing  3p1000nexp-50-20-1-1
#
# writing  3p10sp150x300d
#
# writing  3p50sp150x300d
#
# writing  3p100sp150x300d
#
# writing  3p200sp150x300d
#
# writing  3p1000sp150x300d
#
# writing  3p10nexp-50-20-4-2
#
# writing  3p50nexp-50-20-4-2
#
# writing  3p100nexp-50-20-4-2
#
# writing  3p200nexp-50-20-4-2
#
# writing  3p1000nexp-50-20-4-2
#
# writing  4p1023588
#
# writing  4p5023588
#
# writing  4p10023588
#
# writing  4p20023588
#
# writing  4p100023588
#
# writing  4p10bppc8-02
#
# writing  4p50bppc8-02
#
# writing  4p100bppc8-02
#
# writing  4p200bppc8-02
#
# writing  4p1000bppc8-02
#
# writing  4p10exp-1-500-5-5
#
# writing  4p50exp-1-500-5-5
#
# writing  4p100exp-1-500-5-5
#
# writing  4p200exp-1-500-5-5
#
# writing  4p1000exp-1-500-5-5
#
# writing  4p10mtest4ma
#
# writing  4p50mtest4ma
#
# writing  4p100mtest4ma
#
# writing  4p200mtest4ma
#
# writing  4p1000mtest4ma
#
# writing  4p10neos-1425699
#
# writing  4p50neos-1425699
#
# writing  4p100neos-1425699
#
# writing  4p200neos-1425699
#
# writing  4p1000neos-1425699
#
# writing  4p10neos17
#
# writing  4p50neos17
#
# writing  4p100neos17
#
# writing  4p200neos17
#
# writing  4p1000neos17
#
# writing  4p10nexp-50-20-1-1
#
# writing  4p50nexp-50-20-1-1
#
# writing  4p100nexp-50-20-1-1
#
# writing  4p200nexp-50-20-1-1
#
# writing  4p1000nexp-50-20-1-1
#
# writing  4p10sp150x300d
#
# writing  4p50sp150x300d
#
# writing  4p100sp150x300d
#
# writing  4p200sp150x300d
#
# writing  4p1000sp150x300d
#
# writing  4p10nexp-50-20-4-2
#
# writing  4p50nexp-50-20-4-2
#
# writing  4p100nexp-50-20-4-2
#
# writing  4p200nexp-50-20-4-2
#
# writing  4p1000nexp-50-20-4-2
#
# writing  5p1023588
#
# writing  5p5023588
#
# writing  5p10023588
#
# writing  5p20023588
#
# writing  5p100023588
#
# writing  5p10bppc8-02
#
# writing  5p50bppc8-02
#
# writing  5p100bppc8-02
#
# writing  5p200bppc8-02
#
# writing  5p1000bppc8-02
#
# writing  5p10exp-1-500-5-5
#
# writing  5p50exp-1-500-5-5
#
# writing  5p100exp-1-500-5-5
#
# writing  5p200exp-1-500-5-5
#
# writing  5p1000exp-1-500-5-5
#
# writing  5p10mtest4ma
#
# writing  5p50mtest4ma
#
# writing  5p100mtest4ma
#
# writing  5p200mtest4ma
#
# writing  5p1000mtest4ma
#
# writing  5p10neos-1425699
#
# writing  5p50neos-1425699
#
# writing  5p100neos-1425699
#
# writing  5p200neos-1425699
#
# writing  5p1000neos-1425699
#
# writing  5p10neos17
#
# writing  5p50neos17
#
# writing  5p100neos17
#
# writing  5p200neos17
#
# writing  5p1000neos17
#
# writing  5p10nexp-50-20-1-1
#
# writing  5p50nexp-50-20-1-1
#
# writing  5p100nexp-50-20-1-1
#
# writing  5p200nexp-50-20-1-1
#
# writing  5p1000nexp-50-20-1-1
#
# writing  5p10sp150x300d
#
# writing  5p50sp150x300d
#
# writing  5p100sp150x300d
#
# writing  5p200sp150x300d
#
# writing  5p1000sp150x300d
#
# writing  5p10nexp-50-20-4-2
#
# writing  5p50nexp-50-20-4-2
#
# writing  5p100nexp-50-20-4-2
#
# writing  5p200nexp-50-20-4-2
#
# writing  5p1000nexp-50-20-4-2
#
# writing  6p1023588
#
# writing  6p5023588
#
# writing  6p10023588
#
# writing  6p20023588
#
# writing  6p100023588
#
# writing  6p10bppc8-02
#
# writing  6p50bppc8-02
#
# writing  6p100bppc8-02
#
# writing  6p200bppc8-02
#
# writing  6p1000bppc8-02
#
# writing  6p10exp-1-500-5-5
#
# writing  6p50exp-1-500-5-5
#
# writing  6p100exp-1-500-5-5
#
# writing  6p200exp-1-500-5-5
#
# writing  6p1000exp-1-500-5-5
#
# writing  6p10mtest4ma
#
# writing  6p50mtest4ma
#
# writing  6p100mtest4ma
#
# writing  6p200mtest4ma
#
# writing  6p1000mtest4ma
#
# writing  6p10neos-1425699
#
# writing  6p50neos-1425699
#
# writing  6p100neos-1425699
#
# writing  6p200neos-1425699
#
# writing  6p1000neos-1425699
#
# writing  6p10neos17
#
# writing  6p50neos17
#
# writing  6p100neos17
#
# writing  6p200neos17
#
# writing  6p1000neos17
#
# writing  6p10nexp-50-20-1-1
#
# writing  6p50nexp-50-20-1-1
#
# writing  6p100nexp-50-20-1-1
#
# writing  6p200nexp-50-20-1-1
#
# writing  6p1000nexp-50-20-1-1
#
# writing  6p10sp150x300d
#
# writing  6p50sp150x300d
#
# writing  6p100sp150x300d
#
# writing  6p200sp150x300d
#
# writing  6p1000sp150x300d
#
# writing  6p10nexp-50-20-4-2
#
# writing  6p50nexp-50-20-4-2
#
# writing  6p100nexp-50-20-4-2
#
# writing  6p200nexp-50-20-4-2
#
# writing  6p1000nexp-50-20-4-2
#
# writing  7p1023588
#
# writing  7p5023588
#
# writing  7p10023588
#
# writing  7p20023588
#
# writing  7p100023588
#
# writing  7p10bppc8-02
#
# writing  7p50bppc8-02
#
# writing  7p100bppc8-02
#
# writing  7p200bppc8-02
#
# writing  7p1000bppc8-02
#
# writing  7p10exp-1-500-5-5
#
# writing  7p50exp-1-500-5-5
#
# writing  7p100exp-1-500-5-5
#
# writing  7p200exp-1-500-5-5
#
# writing  7p1000exp-1-500-5-5
#
# writing  7p10mtest4ma
#
# writing  7p50mtest4ma
#
# writing  7p100mtest4ma
#
# writing  7p200mtest4ma
#
# writing  7p1000mtest4ma
#
# writing  7p10neos-1425699
#
# writing  7p50neos-1425699
#
# writing  7p100neos-1425699
#
# writing  7p200neos-1425699
#
# writing  7p1000neos-1425699
#
# writing  7p10neos17
#
# writing  7p50neos17
#
# writing  7p100neos17
#
# writing  7p200neos17
#
# writing  7p1000neos17
#
# writing  7p10nexp-50-20-1-1
#
# writing  7p50nexp-50-20-1-1
#
# writing  7p100nexp-50-20-1-1
#
# writing  7p200nexp-50-20-1-1
#
# writing  7p1000nexp-50-20-1-1
#
# writing  7p10sp150x300d
#
# writing  7p50sp150x300d
#
# writing  7p100sp150x300d
#
# writing  7p200sp150x300d
#
# writing  7p1000sp150x300d
#
# writing  7p10nexp-50-20-4-2
#
# writing  7p50nexp-50-20-4-2
#
# writing  7p100nexp-50-20-4-2
#
# writing  7p200nexp-50-20-4-2
#
# writing  7p1000nexp-50-20-4-2
#
# writing  8p1023588
#
# writing  8p5023588
#
# writing  8p10023588
#
# writing  8p20023588
#
# writing  8p100023588
#
# writing  8p10bppc8-02
#
# writing  8p50bppc8-02
#
# writing  8p100bppc8-02
#
# writing  8p200bppc8-02
#
# writing  8p1000bppc8-02
#
# writing  8p10exp-1-500-5-5
#
# writing  8p50exp-1-500-5-5
#
# writing  8p100exp-1-500-5-5
#
# writing  8p200exp-1-500-5-5
#
# writing  8p1000exp-1-500-5-5
#
# writing  8p10mtest4ma
#
# writing  8p50mtest4ma
#
# writing  8p100mtest4ma
#
# writing  8p200mtest4ma
#
# writing  8p1000mtest4ma
#
# writing  8p10neos-1425699
#
# writing  8p50neos-1425699
#
# writing  8p100neos-1425699
#
# writing  8p200neos-1425699
#
# writing  8p1000neos-1425699
#
# writing  8p10neos17
#
# writing  8p50neos17
#
# writing  8p100neos17
# writing  8p200neos17
#
# writing  8p1000neos17
#
# writing  8p10nexp-50-20-1-1
#
# writing  8p50nexp-50-20-1-1
#
# writing  8p100nexp-50-20-1-1
#
# writing  8p200nexp-50-20-1-1
#
# writing  8p1000nexp-50-20-1-1
#
# writing  8p10sp150x300d
#
# writing  8p50sp150x300d
#
# writing  8p100sp150x300d
#
# writing  8p200sp150x300d
#
# writing  8p1000sp150x300d
#
# writing  8p10nexp-50-20-4-2
#
# writing  8p50nexp-50-20-4-2
#
# writing  8p100nexp-50-20-4-2
#
# writing  8p200nexp-50-20-4-2
#
# writing  8p1000nexp-50-20-4-2
#
# writing  9p1023588
#
# writing  9p5023588
#
# writing  9p10023588
#
# writing  9p20023588
#
# writing  9p100023588
#
# writing  9p10bppc8-02
#
# writing  9p50bppc8-02
#
# writing  9p100bppc8-02
#
# writing  9p200bppc8-02
#
# writing  9p1000bppc8-02
#
# writing  9p10exp-1-500-5-5
#
# writing  9p50exp-1-500-5-5
#
# writing  9p100exp-1-500-5-5
#
# writing  9p200exp-1-500-5-5
#
# writing  9p1000exp-1-500-5-5
#
# writing  9p10mtest4ma
#
# writing  9p50mtest4ma
#
# writing  9p100mtest4ma
#
# writing  9p200mtest4ma
#
# writing  9p1000mtest4ma
#
# writing  9p10neos-1425699
#
# writing  9p50neos-1425699
#
# writing  9p100neos-1425699
#
# writing  9p200neos-1425699
#
# writing  9p1000neos-1425699
#
# writing  9p10neos17
#
# writing  9p50neos17
#
# writing  9p100neos17
#
# writing  9p200neos17
#
# writing  9p1000neos17
#
# writing  9p10nexp-50-20-1-1
#
# writing  9p50nexp-50-20-1-1
#
# writing  9p100nexp-50-20-1-1
#
# writing  9p200nexp-50-20-1-1
#
# writing  9p1000nexp-50-20-1-1
#
# writing  9p10sp150x300d
#
# writing  9p50sp150x300d
#
# writing  9p100sp150x300d
#
# writing  9p200sp150x300d
#
# writing  9p1000sp150x300d
#
# writing  9p10nexp-50-20-4-2
#
# writing  9p50nexp-50-20-4-2
#
# writing  9p100nexp-50-20-4-2
#
# writing  9p200nexp-50-20-4-2
#
# writing  9p1000nexp-50-20-4-2
#
# writing  10p1023588
#
# writing  10p5023588
#
# writing  10p10023588
#
# writing  10p20023588
#
# writing  10p100023588
#
# writing  10p10bppc8-02
#
# writing  10p50bppc8-02
#
# writing  10p100bppc8-02
#
# writing  10p200bppc8-02
#
# writing  10p1000bppc8-02
#
# writing  10p10exp-1-500-5-5
#
# writing  10p50exp-1-500-5-5
#
# writing  10p100exp-1-500-5-5
#
# writing  10p200exp-1-500-5-5
#
# writing  10p1000exp-1-500-5-5
#
# writing  10p10mtest4ma
#
# writing  10p50mtest4ma
#
# writing  10p100mtest4ma
#
# writing  10p200mtest4ma
#
# writing  10p1000mtest4ma
#
# writing  10p10neos-1425699
#
# writing  10p50neos-1425699
#
# writing  10p100neos-1425699
#
# writing  10p200neos-1425699
#
# writing  10p1000neos-1425699
#
# writing  10p10neos17
#
# writing  10p50neos17
#
# writing  10p100neos17
#
# writing  10p200neos17
#
# writing  10p1000neos17
#
# writing  10p10nexp-50-20-1-1
#
# writing  10p50nexp-50-20-1-1
#
# writing  10p100nexp-50-20-1-1
#
# writing  10p200nexp-50-20-1-1
#
# writing  10p1000nexp-50-20-1-1
#
# writing  10p10sp150x300d
#
# writing  10p50sp150x300d
#
# writing  10p100sp150x300d
#
# writing  10p200sp150x300d
#
# writing  10p1000sp150x300d
#
# writing  10p10nexp-50-20-4-2
#
# writing  10p50nexp-50-20-4-2
#
# writing  10p100nexp-50-20-4-2
#
# writing  10p200nexp-50-20-4-2
#
# writing  10p1000nexp-50-20-4-2

# %% [markdown]
# #### INPUT FILES

# %%
cwd = os.getcwd() + '/Test/inputFiles'
print(cwd)

for percent in percentages:
    
    for problem in testSet:
        
        for j in numNearOptimal:
            
            testFileName = percent + str(j) + problem + '.txt'
            fullFName = cwd  +'/' + testFileName
            
            print('writing ',testFileName, '\n')
            with open(fullFName,'w') as f:
                f.write('solver, SCIP')
                f.write('\n')
                f.write('nodeType, 0, 1')
                f.write('\n')
                f.write('alphaValue, 0.01, 0.94, 0.18, 0.95')
                f.write('\n')
                f.write('optimizationProblem, ' + problem + ".mps")
                f.write('\n')
                f.write('requestedNumberSolutions, ' + str(j))
                f.write('\n')
                f.write('percentNearOptimal, ' + str(percentNearOptimal.get(percent)))
                f.write('\n')
                f.write('Verbosity, 1')
                f.write('\n')
                f.write('beta, 0.06, 0.8, 0.99')
                f.write('\n')
                f.write('priorotizedParam, beta, #, The prioritized parameter is set at given value')
                f.write('\n')
                f.write('solutioncutoff, 0.05, 0.8, 0.7, 0.2')
                f.write('\n')
                f.write('depthcutoff, 0')
                f.write('\n')
                f.write('computeDiversity, 1, #, 0 means compute the diversities of captured solutions 1 means write the captured solutions to .csv file')
                f.write('\n')
                f.write('computeDiversityFromCsv, 0, #, 0 means we DONT Have a .csv file hence run GAMS or SCIP, 1 means we are given a .csv file with solutions hence just compute the diversity of the k most diverse solutions; k is represented by the parameter - requestedNumberSolutions')
                f.write('\n')
                f.write('csvFile,')
                f.write('\n')
                f.write('pMostDiverseSolutions, 10')
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/Test/inputFiles
# writing  1p1023588.txt
#
# writing  1p5023588.txt
#
# writing  1p10023588.txt
#
# writing  1p20023588.txt
#
# writing  1p100023588.txt
#
# writing  1p10bppc8-02.txt
#
# writing  1p50bppc8-02.txt
#
# writing  1p100bppc8-02.txt
#
# writing  1p200bppc8-02.txt
#
# writing  1p1000bppc8-02.txt
#
# writing  1p10exp-1-500-5-5.txt
#
# writing  1p50exp-1-500-5-5.txt
#
# writing  1p100exp-1-500-5-5.txt
#
# writing  1p200exp-1-500-5-5.txt
#
# writing  1p1000exp-1-500-5-5.txt
#
# writing  1p10mtest4ma.txt
#
# writing  1p50mtest4ma.txt
#
# writing  1p100mtest4ma.txt
#
# writing  1p200mtest4ma.txt
#
# writing  1p1000mtest4ma.txt
#
# writing  1p10neos-1425699.txt
#
# writing  1p50neos-1425699.txt
#
# writing  1p100neos-1425699.txt
#
# writing  1p200neos-1425699.txt
#
# writing  1p1000neos-1425699.txt
#
# writing  1p10neos17.txt
#
# writing  1p50neos17.txt
#
# writing  1p100neos17.txt
#
# writing  1p200neos17.txt
#
# writing  1p1000neos17.txt
#
# writing  1p10nexp-50-20-1-1.txt
#
# writing  1p50nexp-50-20-1-1.txt
#
# writing  1p100nexp-50-20-1-1.txt
#
# writing  1p200nexp-50-20-1-1.txt
#
# writing  1p1000nexp-50-20-1-1.txt
#
# writing  1p10sp150x300d.txt
#
# writing  1p50sp150x300d.txt
#
# writing  1p100sp150x300d.txt
#
# writing  1p200sp150x300d.txt
#
# writing  1p1000sp150x300d.txt
#
# writing  1p10nexp-50-20-4-2.txt
#
# writing  1p50nexp-50-20-4-2.txt
#
# writing  1p100nexp-50-20-4-2.txt
#
# writing  1p200nexp-50-20-4-2.txt
#
# writing  1p1000nexp-50-20-4-2.txt
#
# writing  2p1023588.txt
#
# writing  2p5023588.txt
#
# writing  2p10023588.txt
#
# writing  2p20023588.txt
#
# writing  2p100023588.txt
#
# writing  2p10bppc8-02.txt
#
# writing  2p50bppc8-02.txt
#
# writing  2p100bppc8-02.txt
#
# writing  2p200bppc8-02.txt
#
# writing  2p1000bppc8-02.txt
#
# writing  2p10exp-1-500-5-5.txt
#
# writing  2p50exp-1-500-5-5.txt
#
# writing  2p100exp-1-500-5-5.txt
#
# writing  2p200exp-1-500-5-5.txt
#
# writing  2p1000exp-1-500-5-5.txt
#
# writing  2p10mtest4ma.txt
#
# writing  2p50mtest4ma.txt
#
# writing  2p100mtest4ma.txt
#
# writing  2p200mtest4ma.txt
#
# writing  2p1000mtest4ma.txt
#
# writing  2p10neos-1425699.txt
#
# writing  2p50neos-1425699.txt
#
# writing  2p100neos-1425699.txt
#
# writing  2p200neos-1425699.txt
#
# writing  2p1000neos-1425699.txt
#
# writing  2p10neos17.txt
#
# writing  2p50neos17.txt
#
# writing  2p100neos17.txt
#
# writing  2p200neos17.txt
#
# writing  2p1000neos17.txt
#
# writing  2p10nexp-50-20-1-1.txt
#
# writing  2p50nexp-50-20-1-1.txt
#
# writing  2p100nexp-50-20-1-1.txt
#
# writing  2p200nexp-50-20-1-1.txt
#
# writing  2p1000nexp-50-20-1-1.txt
#
# writing  2p10sp150x300d.txt
#
# writing  2p50sp150x300d.txt
#
# writing  2p100sp150x300d.txt
#
# writing  2p200sp150x300d.txt
#
# writing  2p1000sp150x300d.txt
#
# writing  2p10nexp-50-20-4-2.txt
#
# writing  2p50nexp-50-20-4-2.txt
#
# writing  2p100nexp-50-20-4-2.txt
#
# writing  2p200nexp-50-20-4-2.txt
#
# writing  2p1000nexp-50-20-4-2.txt
#
# writing  3p1023588.txt
#
# writing  3p5023588.txt
#
# writing  3p10023588.txt
#
# writing  3p20023588.txt
#
# writing  3p100023588.txt
#
# writing  3p10bppc8-02.txt
#
# writing  3p50bppc8-02.txt
#
# writing  3p100bppc8-02.txt
#
# writing  3p200bppc8-02.txt
#
# writing  3p1000bppc8-02.txt
#
# writing  3p10exp-1-500-5-5.txt
#
# writing  3p50exp-1-500-5-5.txt
#
# writing  3p100exp-1-500-5-5.txt
#
# writing  3p200exp-1-500-5-5.txt
#
# writing  3p1000exp-1-500-5-5.txt
#
# writing  3p10mtest4ma.txt
#
# writing  3p50mtest4ma.txt
#
# writing  3p100mtest4ma.txt
#
# writing  3p200mtest4ma.txt
#
# writing  3p1000mtest4ma.txt
#
# writing  3p10neos-1425699.txt
#
# writing  3p50neos-1425699.txt
#
# writing  3p100neos-1425699.txt
#
# writing  3p200neos-1425699.txt
#
# writing  3p1000neos-1425699.txt
#
# writing  3p10neos17.txt
#
# writing  3p50neos17.txt
#
# writing  3p100neos17.txt
#
# writing  3p200neos17.txt
#
# writing  3p1000neos17.txt
#
# writing  3p10nexp-50-20-1-1.txt
#
# writing  3p50nexp-50-20-1-1.txt
#
# writing  3p100nexp-50-20-1-1.txt
#
# writing  3p200nexp-50-20-1-1.txt
#
# writing  3p1000nexp-50-20-1-1.txt
#
# writing  3p10sp150x300d.txt
#
# writing  3p50sp150x300d.txt
#
# writing  3p100sp150x300d.txt
#
# writing  3p200sp150x300d.txt
#
# writing  3p1000sp150x300d.txt
#
# writing  3p10nexp-50-20-4-2.txt
#
# writing  3p50nexp-50-20-4-2.txt
#
# writing  3p100nexp-50-20-4-2.txt
#
# writing  3p200nexp-50-20-4-2.txt
#
# writing  3p1000nexp-50-20-4-2.txt
#
# writing  4p1023588.txt
#
# writing  4p5023588.txt
#
# writing  4p10023588.txt
#
# writing  4p20023588.txt
#
# writing  4p100023588.txt
#
# writing  4p10bppc8-02.txt
#
# writing  4p50bppc8-02.txt
#
# writing  4p100bppc8-02.txt
#
# writing  4p200bppc8-02.txt
#
# writing  4p1000bppc8-02.txt
#
# writing  4p10exp-1-500-5-5.txt
#
# writing  4p50exp-1-500-5-5.txt
#
# writing  4p100exp-1-500-5-5.txt
#
# writing  4p200exp-1-500-5-5.txt
#
# writing  4p1000exp-1-500-5-5.txt
#
# writing  4p10mtest4ma.txt
#
# writing  4p50mtest4ma.txt
#
# writing  4p100mtest4ma.txt
#
# writing  4p200mtest4ma.txt
#
# writing  4p1000mtest4ma.txt
#
# writing  4p10neos-1425699.txt
#
# writing  4p50neos-1425699.txt
#
# writing  4p100neos-1425699.txt
#
# writing  4p200neos-1425699.txt
#
# writing  4p1000neos-1425699.txt
#
# writing  4p10neos17.txt
#
# writing  4p50neos17.txt
#
# writing  4p100neos17.txt
#
# writing  4p200neos17.txt
#
# writing  4p1000neos17.txt
#
# writing  4p10nexp-50-20-1-1.txt
#
# writing  4p50nexp-50-20-1-1.txt
#
# writing  4p100nexp-50-20-1-1.txt
#
# writing  4p200nexp-50-20-1-1.txt
#
# writing  4p1000nexp-50-20-1-1.txt
#
# writing  4p10sp150x300d.txt
#
# writing  4p50sp150x300d.txt
#
# writing  4p100sp150x300d.txt
#
# writing  4p200sp150x300d.txt
#
# writing  4p1000sp150x300d.txt
#
# writing  4p10nexp-50-20-4-2.txt
#
# writing  4p50nexp-50-20-4-2.txt
#
# writing  4p100nexp-50-20-4-2.txt
#
# writing  4p200nexp-50-20-4-2.txt
#
# writing  4p1000nexp-50-20-4-2.txt
#
# writing  5p1023588.txt
#
# writing  5p5023588.txt
#
# writing  5p10023588.txt
#
# writing  5p20023588.txt
#
# writing  5p100023588.txt
#
# writing  5p10bppc8-02.txt
#
# writing  5p50bppc8-02.txt
#
# writing  5p100bppc8-02.txt
#
# writing  5p200bppc8-02.txt
#
# writing  5p1000bppc8-02.txt
#
# writing  5p10exp-1-500-5-5.txt
#
# writing  5p50exp-1-500-5-5.txt
#
# writing  5p100exp-1-500-5-5.txt
#
# writing  5p200exp-1-500-5-5.txt
#
# writing  5p1000exp-1-500-5-5.txt
#
# writing  5p10mtest4ma.txt
#
# writing  5p50mtest4ma.txt
#
# writing  5p100mtest4ma.txt
#
# writing  5p200mtest4ma.txt
#
# writing  5p1000mtest4ma.txt
#
# writing  5p10neos-1425699.txt
#
# writing  5p50neos-1425699.txt
#
# writing  5p100neos-1425699.txt
#
# writing  5p200neos-1425699.txt
#
# writing  5p1000neos-1425699.txt
#
# writing  5p10neos17.txt
#
# writing  5p50neos17.txt
#
# writing  5p100neos17.txt
#
# writing  5p200neos17.txt
#
# writing  5p1000neos17.txt
#
# writing  5p10nexp-50-20-1-1.txt
#
# writing  5p50nexp-50-20-1-1.txt
#
# writing  5p100nexp-50-20-1-1.txt
#
# writing  5p200nexp-50-20-1-1.txt
#
# writing  5p1000nexp-50-20-1-1.txt
#
# writing  5p10sp150x300d.txt
#
# writing  5p50sp150x300d.txt
#
# writing  5p100sp150x300d.txt
#
# writing  5p200sp150x300d.txt
#
# writing  5p1000sp150x300d.txt
#
# writing  5p10nexp-50-20-4-2.txt
#
# writing  5p50nexp-50-20-4-2.txt
#
# writing  5p100nexp-50-20-4-2.txt
#
# writing  5p200nexp-50-20-4-2.txt
#
# writing  5p1000nexp-50-20-4-2.txt
#
# writing  6p1023588.txt
#
# writing  6p5023588.txt
#
# writing  6p10023588.txt
#
# writing  6p20023588.txt
#
# writing  6p100023588.txt
#
# writing  6p10bppc8-02.txt
#
# writing  6p50bppc8-02.txt
#
# writing  6p100bppc8-02.txt
#
# writing  6p200bppc8-02.txt
#
# writing  6p1000bppc8-02.txt
#
# writing  6p10exp-1-500-5-5.txt
#
# writing  6p50exp-1-500-5-5.txt
#
# writing  6p100exp-1-500-5-5.txt
#
# writing  6p200exp-1-500-5-5.txt
#
# writing  6p1000exp-1-500-5-5.txt
#
# writing  6p10mtest4ma.txt
#
# writing  6p50mtest4ma.txt
#
# writing  6p100mtest4ma.txt
#
# writing  6p200mtest4ma.txt
#
# writing  6p1000mtest4ma.txt
#
# writing  6p10neos-1425699.txt
#
# writing  6p50neos-1425699.txt
#
# writing  6p100neos-1425699.txt
#
# writing  6p200neos-1425699.txt
#
# writing  6p1000neos-1425699.txt
#
# writing  6p10neos17.txt
#
# writing  6p50neos17.txt
#
# writing  6p100neos17.txt
#
# writing  6p200neos17.txt
#
# writing  6p1000neos17.txt
#
# writing  6p10nexp-50-20-1-1.txt
#
# writing  6p50nexp-50-20-1-1.txt
#
# writing  6p100nexp-50-20-1-1.txt
#
# writing  6p200nexp-50-20-1-1.txt
#
# writing  6p1000nexp-50-20-1-1.txt
#
# writing  6p10sp150x300d.txt
#
# writing  6p50sp150x300d.txt
#
# writing  6p100sp150x300d.txt
#
# writing  6p200sp150x300d.txt
#
# writing  6p1000sp150x300d.txt
#
# writing  6p10nexp-50-20-4-2.txt
#
# writing  6p50nexp-50-20-4-2.txt
#
# writing  6p100nexp-50-20-4-2.txt
#
# writing  6p200nexp-50-20-4-2.txt
#
# writing  6p1000nexp-50-20-4-2.txt
#
# writing  7p1023588.txt
#
# writing  7p5023588.txt
#
# writing  7p10023588.txt
#
# writing  7p20023588.txt
#
# writing  7p100023588.txt
#
# writing  7p10bppc8-02.txt
#
# writing  7p50bppc8-02.txt
#
# writing  7p100bppc8-02.txt
#
# writing  7p200bppc8-02.txt
#
# writing  7p1000bppc8-02.txt
#
# writing  7p10exp-1-500-5-5.txt
#
# writing  7p50exp-1-500-5-5.txt
#
# writing  7p100exp-1-500-5-5.txt
#
# writing  7p200exp-1-500-5-5.txt
#
# writing  7p1000exp-1-500-5-5.txt
#
# writing  7p10mtest4ma.txt
#
# writing  7p50mtest4ma.txt
#
# writing  7p100mtest4ma.txt
#
# writing  7p200mtest4ma.txt
#
# writing  7p1000mtest4ma.txt
#
# writing  7p10neos-1425699.txt
#
# writing  7p50neos-1425699.txt
#
# writing  7p100neos-1425699.txt
#
# writing  7p200neos-1425699.txt
#
# writing  7p1000neos-1425699.txt
#
# writing  7p10neos17.txt
#
# writing  7p50neos17.txt
#
# writing  7p100neos17.txt
#
# writing  7p200neos17.txt
#
# writing  7p1000neos17.txt
#
# writing  7p10nexp-50-20-1-1.txt
#
# writing  7p50nexp-50-20-1-1.txt
#
# writing  7p100nexp-50-20-1-1.txt
#
# writing  7p200nexp-50-20-1-1.txt
#
# writing  7p1000nexp-50-20-1-1.txt
#
# writing  7p10sp150x300d.txt
#
# writing  7p50sp150x300d.txt
#
# writing  7p100sp150x300d.txt
#
# writing  7p200sp150x300d.txt
#
# writing  7p1000sp150x300d.txt
#
# writing  7p10nexp-50-20-4-2.txt
#
# writing  7p50nexp-50-20-4-2.txt
#
# writing  7p100nexp-50-20-4-2.txt
#
# writing  7p200nexp-50-20-4-2.txt
#
# writing  7p1000nexp-50-20-4-2.txt
#
# writing  8p1023588.txt
#
# writing  8p5023588.txt
#
# writing  8p10023588.txt
#
# writing  8p20023588.txt
#
# writing  8p100023588.txt
#
# writing  8p10bppc8-02.txt
#
# writing  8p50bppc8-02.txt
#
# writing  8p100bppc8-02.txt
#
# writing  8p200bppc8-02.txt
#
# writing  8p1000bppc8-02.txt
#
# writing  8p10exp-1-500-5-5.txt
#
# writing  8p50exp-1-500-5-5.txt
#
# writing  8p100exp-1-500-5-5.txt
#
# writing  8p200exp-1-500-5-5.txt
#
# writing  8p1000exp-1-500-5-5.txt
#
# writing  8p10mtest4ma.txt
#
# writing  8p50mtest4ma.txt
#
# writing  8p100mtest4ma.txt
#
# writing  8p200mtest4ma.txt
#
# writing  8p1000mtest4ma.txt
#
# writing  8p10neos-1425699.txt
#
# writing  8p50neos-1425699.txt
#
# writing  8p100neos-1425699.txt
#
# writing  8p200neos-1425699.txt
#
# writing  8p1000neos-1425699.txt
#
# writing  8p10neos17.txt
#
# writing  8p50neos17.txt
#
# writing  8p100neos17.txt
#
# writing  8p200neos17.txt
#
# writing  8p1000neos17.txt
#
# writing  8p10nexp-50-20-1-1.txt
#
# writing  8p50nexp-50-20-1-1.txt
#
# writing  8p100nexp-50-20-1-1.txt
#
# writing  8p200nexp-50-20-1-1.txt
#
# writing  8p1000nexp-50-20-1-1.txt
#
# writing  8p10sp150x300d.txt
#
# writing  8p50sp150x300d.txt
#
# writing  8p100sp150x300d.txt
#
# writing  8p200sp150x300d.txt
#
# writing  8p1000sp150x300d.txt
#
# writing  8p10nexp-50-20-4-2.txt
# writing  8p50nexp-50-20-4-2.txt
#
# writing  8p100nexp-50-20-4-2.txt
#
# writing  8p200nexp-50-20-4-2.txt
#
# writing  8p1000nexp-50-20-4-2.txt
#
# writing  9p1023588.txt
#
# writing  9p5023588.txt
#
# writing  9p10023588.txt
#
# writing  9p20023588.txt
#
# writing  9p100023588.txt
#
# writing  9p10bppc8-02.txt
#
# writing  9p50bppc8-02.txt
#
# writing  9p100bppc8-02.txt
#
# writing  9p200bppc8-02.txt
#
# writing  9p1000bppc8-02.txt
#
# writing  9p10exp-1-500-5-5.txt
#
# writing  9p50exp-1-500-5-5.txt
#
# writing  9p100exp-1-500-5-5.txt
#
# writing  9p200exp-1-500-5-5.txt
#
# writing  9p1000exp-1-500-5-5.txt
#
# writing  9p10mtest4ma.txt
#
# writing  9p50mtest4ma.txt
#
# writing  9p100mtest4ma.txt
#
# writing  9p200mtest4ma.txt
#
# writing  9p1000mtest4ma.txt
#
# writing  9p10neos-1425699.txt
#
# writing  9p50neos-1425699.txt
#
# writing  9p100neos-1425699.txt
#
# writing  9p200neos-1425699.txt
#
# writing  9p1000neos-1425699.txt
#
# writing  9p10neos17.txt
#
# writing  9p50neos17.txt
#
# writing  9p100neos17.txt
#
# writing  9p200neos17.txt
#
# writing  9p1000neos17.txt
#
# writing  9p10nexp-50-20-1-1.txt
#
# writing  9p50nexp-50-20-1-1.txt
#
# writing  9p100nexp-50-20-1-1.txt
#
# writing  9p200nexp-50-20-1-1.txt
#
# writing  9p1000nexp-50-20-1-1.txt
#
# writing  9p10sp150x300d.txt
#
# writing  9p50sp150x300d.txt
#
# writing  9p100sp150x300d.txt
#
# writing  9p200sp150x300d.txt
#
# writing  9p1000sp150x300d.txt
#
# writing  9p10nexp-50-20-4-2.txt
#
# writing  9p50nexp-50-20-4-2.txt
#
# writing  9p100nexp-50-20-4-2.txt
#
# writing  9p200nexp-50-20-4-2.txt
#
# writing  9p1000nexp-50-20-4-2.txt
#
# writing  10p1023588.txt
#
# writing  10p5023588.txt
#
# writing  10p10023588.txt
#
# writing  10p20023588.txt
#
# writing  10p100023588.txt
#
# writing  10p10bppc8-02.txt
#
# writing  10p50bppc8-02.txt
#
# writing  10p100bppc8-02.txt
#
# writing  10p200bppc8-02.txt
#
# writing  10p1000bppc8-02.txt
#
# writing  10p10exp-1-500-5-5.txt
#
# writing  10p50exp-1-500-5-5.txt
#
# writing  10p100exp-1-500-5-5.txt
#
# writing  10p200exp-1-500-5-5.txt
#
# writing  10p1000exp-1-500-5-5.txt
#
# writing  10p10mtest4ma.txt
#
# writing  10p50mtest4ma.txt
#
# writing  10p100mtest4ma.txt
#
# writing  10p200mtest4ma.txt
#
# writing  10p1000mtest4ma.txt
#
# writing  10p10neos-1425699.txt
#
# writing  10p50neos-1425699.txt
#
# writing  10p100neos-1425699.txt
#
# writing  10p200neos-1425699.txt
#
# writing  10p1000neos-1425699.txt
#
# writing  10p10neos17.txt
#
# writing  10p50neos17.txt
#
# writing  10p100neos17.txt
#
# writing  10p200neos17.txt
#
# writing  10p1000neos17.txt
#
# writing  10p10nexp-50-20-1-1.txt
#
# writing  10p50nexp-50-20-1-1.txt
#
# writing  10p100nexp-50-20-1-1.txt
#
# writing  10p200nexp-50-20-1-1.txt
#
# writing  10p1000nexp-50-20-1-1.txt
#
# writing  10p10sp150x300d.txt
#
# writing  10p50sp150x300d.txt
#
# writing  10p100sp150x300d.txt
#
# writing  10p200sp150x300d.txt
#
# writing  10p1000sp150x300d.txt
#
# writing  10p10nexp-50-20-4-2.txt
#
# writing  10p50nexp-50-20-4-2.txt
#
# writing  10p100nexp-50-20-4-2.txt
#
# writing  10p200nexp-50-20-4-2.txt
#
# writing  10p1000nexp-50-20-4-2.txt

# %% [markdown]
# #### ISAAC COMMAND TO SUBMIT ALL JOBS

# %%
cwd = os.getcwd() + '/submitAllJobs'
print(cwd)

allJobsFName = cwd + '/allTestjobs'

f = open(allJobsFName,'w')
f.write('#!/bin/bash')
f.write('\n')
f.close()

for percent in percentages:
    
    for problem in testSet:
        
        for j in numNearOptimal:
            
            fName = percent + str(j) + problem
            
            print('writing ',fName)
            with open(allJobsFName,'a') as f:
                f.write('qsub ' + fName)
                f.write('\n')
# Out:
# /Users/izuwaahanor/Documents/Research/DiverseNearOptimal/runFiles/submitAllJobs
# writing  1p1023588
# writing  1p5023588
# writing  1p10023588
# writing  1p20023588
# writing  1p100023588
# writing  1p10bppc8-02
# writing  1p50bppc8-02
# writing  1p100bppc8-02
# writing  1p200bppc8-02
# writing  1p1000bppc8-02
# writing  1p10exp-1-500-5-5
# writing  1p50exp-1-500-5-5
# writing  1p100exp-1-500-5-5
# writing  1p200exp-1-500-5-5
# writing  1p1000exp-1-500-5-5
# writing  1p10mtest4ma
# writing  1p50mtest4ma
# writing  1p100mtest4ma
# writing  1p200mtest4ma
# writing  1p1000mtest4ma
# writing  1p10neos-1425699
# writing  1p50neos-1425699
# writing  1p100neos-1425699
# writing  1p200neos-1425699
# writing  1p1000neos-1425699
# writing  1p10neos17
# writing  1p50neos17
# writing  1p100neos17
# writing  1p200neos17
# writing  1p1000neos17
# writing  1p10nexp-50-20-1-1
# writing  1p50nexp-50-20-1-1
# writing  1p100nexp-50-20-1-1
# writing  1p200nexp-50-20-1-1
# writing  1p1000nexp-50-20-1-1
# writing  1p10sp150x300d
# writing  1p50sp150x300d
# writing  1p100sp150x300d
# writing  1p200sp150x300d
# writing  1p1000sp150x300d
# writing  1p10nexp-50-20-4-2
# writing  1p50nexp-50-20-4-2
# writing  1p100nexp-50-20-4-2
# writing  1p200nexp-50-20-4-2
# writing  1p1000nexp-50-20-4-2
# writing  2p1023588
# writing  2p5023588
# writing  2p10023588
# writing  2p20023588
# writing  2p100023588
# writing  2p10bppc8-02
# writing  2p50bppc8-02
# writing  2p100bppc8-02
# writing  2p200bppc8-02
# writing  2p1000bppc8-02
# writing  2p10exp-1-500-5-5
# writing  2p50exp-1-500-5-5
# writing  2p100exp-1-500-5-5
# writing  2p200exp-1-500-5-5
# writing  2p1000exp-1-500-5-5
# writing  2p10mtest4ma
# writing  2p50mtest4ma
# writing  2p100mtest4ma
# writing  2p200mtest4ma
# writing  2p1000mtest4ma
# writing  2p10neos-1425699
# writing  2p50neos-1425699
# writing  2p100neos-1425699
# writing  2p200neos-1425699
# writing  2p1000neos-1425699
# writing  2p10neos17
# writing  2p50neos17
# writing  2p100neos17
# writing  2p200neos17
# writing  2p1000neos17
# writing  2p10nexp-50-20-1-1
# writing  2p50nexp-50-20-1-1
# writing  2p100nexp-50-20-1-1
# writing  2p200nexp-50-20-1-1
# writing  2p1000nexp-50-20-1-1
# writing  2p10sp150x300d
# writing  2p50sp150x300d
# writing  2p100sp150x300d
# writing  2p200sp150x300d
# writing  2p1000sp150x300d
# writing  2p10nexp-50-20-4-2
# writing  2p50nexp-50-20-4-2
# writing  2p100nexp-50-20-4-2
# writing  2p200nexp-50-20-4-2
# writing  2p1000nexp-50-20-4-2
# writing  3p1023588
# writing  3p5023588
# writing  3p10023588
# writing  3p20023588
# writing  3p100023588
# writing  3p10bppc8-02
# writing  3p50bppc8-02
# writing  3p100bppc8-02
# writing  3p200bppc8-02
# writing  3p1000bppc8-02
# writing  3p10exp-1-500-5-5
# writing  3p50exp-1-500-5-5
# writing  3p100exp-1-500-5-5
# writing  3p200exp-1-500-5-5
# writing  3p1000exp-1-500-5-5
# writing  3p10mtest4ma
# writing  3p50mtest4ma
# writing  3p100mtest4ma
# writing  3p200mtest4ma
# writing  3p1000mtest4ma
# writing  3p10neos-1425699
# writing  3p50neos-1425699
# writing  3p100neos-1425699
# writing  3p200neos-1425699
# writing  3p1000neos-1425699
# writing  3p10neos17
# writing  3p50neos17
# writing  3p100neos17
# writing  3p200neos17
# writing  3p1000neos17
# writing  3p10nexp-50-20-1-1
# writing  3p50nexp-50-20-1-1
# writing  3p100nexp-50-20-1-1
# writing  3p200nexp-50-20-1-1
# writing  3p1000nexp-50-20-1-1
# writing  3p10sp150x300d
# writing  3p50sp150x300d
# writing  3p100sp150x300d
# writing  3p200sp150x300d
# writing  3p1000sp150x300d
# writing  3p10nexp-50-20-4-2
# writing  3p50nexp-50-20-4-2
# writing  3p100nexp-50-20-4-2
# writing  3p200nexp-50-20-4-2
# writing  3p1000nexp-50-20-4-2
# writing  4p1023588
# writing  4p5023588
# writing  4p10023588
# writing  4p20023588
# writing  4p100023588
# writing  4p10bppc8-02
# writing  4p50bppc8-02
# writing  4p100bppc8-02
# writing  4p200bppc8-02
# writing  4p1000bppc8-02
# writing  4p10exp-1-500-5-5
# writing  4p50exp-1-500-5-5
# writing  4p100exp-1-500-5-5
# writing  4p200exp-1-500-5-5
# writing  4p1000exp-1-500-5-5
# writing  4p10mtest4ma
# writing  4p50mtest4ma
# writing  4p100mtest4ma
# writing  4p200mtest4ma
# writing  4p1000mtest4ma
# writing  4p10neos-1425699
# writing  4p50neos-1425699
# writing  4p100neos-1425699
# writing  4p200neos-1425699
# writing  4p1000neos-1425699
# writing  4p10neos17
# writing  4p50neos17
# writing  4p100neos17
# writing  4p200neos17
# writing  4p1000neos17
# writing  4p10nexp-50-20-1-1
# writing  4p50nexp-50-20-1-1
# writing  4p100nexp-50-20-1-1
# writing  4p200nexp-50-20-1-1
# writing  4p1000nexp-50-20-1-1
# writing  4p10sp150x300d
# writing  4p50sp150x300d
# writing  4p100sp150x300d
# writing  4p200sp150x300d
# writing  4p1000sp150x300d
# writing  4p10nexp-50-20-4-2
# writing  4p50nexp-50-20-4-2
# writing  4p100nexp-50-20-4-2
# writing  4p200nexp-50-20-4-2
# writing  4p1000nexp-50-20-4-2
# writing  5p1023588
# writing  5p5023588
# writing  5p10023588
# writing  5p20023588
# writing  5p100023588
# writing  5p10bppc8-02
# writing  5p50bppc8-02
# writing  5p100bppc8-02
# writing  5p200bppc8-02
# writing  5p1000bppc8-02
# writing  5p10exp-1-500-5-5
# writing  5p50exp-1-500-5-5
# writing  5p100exp-1-500-5-5
# writing  5p200exp-1-500-5-5
# writing  5p1000exp-1-500-5-5
# writing  5p10mtest4ma
# writing  5p50mtest4ma
# writing  5p100mtest4ma
# writing  5p200mtest4ma
# writing  5p1000mtest4ma
# writing  5p10neos-1425699
# writing  5p50neos-1425699
# writing  5p100neos-1425699
# writing  5p200neos-1425699
# writing  5p1000neos-1425699
# writing  5p10neos17
# writing  5p50neos17
# writing  5p100neos17
# writing  5p200neos17
# writing  5p1000neos17
# writing  5p10nexp-50-20-1-1
# writing  5p50nexp-50-20-1-1
# writing  5p100nexp-50-20-1-1
# writing  5p200nexp-50-20-1-1
# writing  5p1000nexp-50-20-1-1
# writing  5p10sp150x300d
# writing  5p50sp150x300d
# writing  5p100sp150x300d
# writing  5p200sp150x300d
# writing  5p1000sp150x300d
# writing  5p10nexp-50-20-4-2
# writing  5p50nexp-50-20-4-2
# writing  5p100nexp-50-20-4-2
# writing  5p200nexp-50-20-4-2
# writing  5p1000nexp-50-20-4-2
# writing  6p1023588
# writing  6p5023588
# writing  6p10023588
# writing  6p20023588
# writing  6p100023588
# writing  6p10bppc8-02
# writing  6p50bppc8-02
# writing  6p100bppc8-02
# writing  6p200bppc8-02
# writing  6p1000bppc8-02
# writing  6p10exp-1-500-5-5
# writing  6p50exp-1-500-5-5
# writing  6p100exp-1-500-5-5
# writing  6p200exp-1-500-5-5
# writing  6p1000exp-1-500-5-5
# writing  6p10mtest4ma
# writing  6p50mtest4ma
# writing  6p100mtest4ma
# writing  6p200mtest4ma
# writing  6p1000mtest4ma
# writing  6p10neos-1425699
# writing  6p50neos-1425699
# writing  6p100neos-1425699
# writing  6p200neos-1425699
# writing  6p1000neos-1425699
# writing  6p10neos17
# writing  6p50neos17
# writing  6p100neos17
# writing  6p200neos17
# writing  6p1000neos17
# writing  6p10nexp-50-20-1-1
# writing  6p50nexp-50-20-1-1
# writing  6p100nexp-50-20-1-1
# writing  6p200nexp-50-20-1-1
# writing  6p1000nexp-50-20-1-1
# writing  6p10sp150x300d
# writing  6p50sp150x300d
# writing  6p100sp150x300d
# writing  6p200sp150x300d
# writing  6p1000sp150x300d
# writing  6p10nexp-50-20-4-2
# writing  6p50nexp-50-20-4-2
# writing  6p100nexp-50-20-4-2
# writing  6p200nexp-50-20-4-2
# writing  6p1000nexp-50-20-4-2
# writing  7p1023588
# writing  7p5023588
# writing  7p10023588
# writing  7p20023588
# writing  7p100023588
# writing  7p10bppc8-02
# writing  7p50bppc8-02
# writing  7p100bppc8-02
# writing  7p200bppc8-02
# writing  7p1000bppc8-02
# writing  7p10exp-1-500-5-5
# writing  7p50exp-1-500-5-5
# writing  7p100exp-1-500-5-5
# writing  7p200exp-1-500-5-5
# writing  7p1000exp-1-500-5-5
# writing  7p10mtest4ma
# writing  7p50mtest4ma
# writing  7p100mtest4ma
# writing  7p200mtest4ma
# writing  7p1000mtest4ma
# writing  7p10neos-1425699
# writing  7p50neos-1425699
# writing  7p100neos-1425699
# writing  7p200neos-1425699
# writing  7p1000neos-1425699
# writing  7p10neos17
# writing  7p50neos17
# writing  7p100neos17
# writing  7p200neos17
# writing  7p1000neos17
# writing  7p10nexp-50-20-1-1
# writing  7p50nexp-50-20-1-1
# writing  7p100nexp-50-20-1-1
# writing  7p200nexp-50-20-1-1
# writing  7p1000nexp-50-20-1-1
# writing  7p10sp150x300d
# writing  7p50sp150x300d
# writing  7p100sp150x300d
# writing  7p200sp150x300d
# writing  7p1000sp150x300d
# writing  7p10nexp-50-20-4-2
# writing  7p50nexp-50-20-4-2
# writing  7p100nexp-50-20-4-2
# writing  7p200nexp-50-20-4-2
# writing  7p1000nexp-50-20-4-2
# writing  8p1023588
# writing  8p5023588
# writing  8p10023588
# writing  8p20023588
# writing  8p100023588
# writing  8p10bppc8-02
# writing  8p50bppc8-02
# writing  8p100bppc8-02
# writing  8p200bppc8-02
# writing  8p1000bppc8-02
# writing  8p10exp-1-500-5-5
# writing  8p50exp-1-500-5-5
# writing  8p100exp-1-500-5-5
# writing  8p200exp-1-500-5-5
# writing  8p1000exp-1-500-5-5
# writing  8p10mtest4ma
# writing  8p50mtest4ma
# writing  8p100mtest4ma
# writing  8p200mtest4ma
# writing  8p1000mtest4ma
# writing  8p10neos-1425699
# writing  8p50neos-1425699
# writing  8p100neos-1425699
# writing  8p200neos-1425699
# writing  8p1000neos-1425699
# writing  8p10neos17
# writing  8p50neos17
# writing  8p100neos17
# writing  8p200neos17
# writing  8p1000neos17
# writing  8p10nexp-50-20-1-1
# writing  8p50nexp-50-20-1-1
# writing  8p100nexp-50-20-1-1
# writing  8p200nexp-50-20-1-1
# writing  8p1000nexp-50-20-1-1
# writing  8p10sp150x300d
# writing  8p50sp150x300d
# writing  8p100sp150x300d
# writing  8p200sp150x300d
# writing  8p1000sp150x300d
# writing  8p10nexp-50-20-4-2
# writing  8p50nexp-50-20-4-2
# writing  8p100nexp-50-20-4-2
# writing  8p200nexp-50-20-4-2
# writing  8p1000nexp-50-20-4-2
# writing  9p1023588
# writing  9p5023588
# writing  9p10023588
# writing  9p20023588
# writing  9p100023588
# writing  9p10bppc8-02
# writing  9p50bppc8-02
# writing  9p100bppc8-02
# writing  9p200bppc8-02
# writing  9p1000bppc8-02
# writing  9p10exp-1-500-5-5
# writing  9p50exp-1-500-5-5
# writing  9p100exp-1-500-5-5
# writing  9p200exp-1-500-5-5
# writing  9p1000exp-1-500-5-5
# writing  9p10mtest4ma
# writing  9p50mtest4ma
# writing  9p100mtest4ma
# writing  9p200mtest4ma
# writing  9p1000mtest4ma
# writing  9p10neos-1425699
# writing  9p50neos-1425699
# writing  9p100neos-1425699
# writing  9p200neos-1425699
# writing  9p1000neos-1425699
# writing  9p10neos17
# writing  9p50neos17
# writing  9p100neos17
# writing  9p200neos17
# writing  9p1000neos17
# writing  9p10nexp-50-20-1-1
# writing  9p50nexp-50-20-1-1
# writing  9p100nexp-50-20-1-1
# writing  9p200nexp-50-20-1-1
# writing  9p1000nexp-50-20-1-1
# writing  9p10sp150x300d
# writing  9p50sp150x300d
# writing  9p100sp150x300d
# writing  9p200sp150x300d
# writing  9p1000sp150x300d
# writing  9p10nexp-50-20-4-2
# writing  9p50nexp-50-20-4-2
# writing  9p100nexp-50-20-4-2
# writing  9p200nexp-50-20-4-2
# writing  9p1000nexp-50-20-4-2
# writing  10p1023588
# writing  10p5023588
# writing  10p10023588
# writing  10p20023588
# writing  10p100023588
# writing  10p10bppc8-02
# writing  10p50bppc8-02
# writing  10p100bppc8-02
# writing  10p200bppc8-02
# writing  10p1000bppc8-02
# writing  10p10exp-1-500-5-5
# writing  10p50exp-1-500-5-5
# writing  10p100exp-1-500-5-5
# writing  10p200exp-1-500-5-5
# writing  10p1000exp-1-500-5-5
# writing  10p10mtest4ma
# writing  10p50mtest4ma
# writing  10p100mtest4ma
# writing  10p200mtest4ma
# writing  10p1000mtest4ma
# writing  10p10neos-1425699
# writing  10p50neos-1425699
# writing  10p100neos-1425699
# writing  10p200neos-1425699
# writing  10p1000neos-1425699
# writing  10p10neos17
# writing  10p50neos17
# writing  10p100neos17
# writing  10p200neos17
# writing  10p1000neos17
# writing  10p10nexp-50-20-1-1
# writing  10p50nexp-50-20-1-1
# writing  10p100nexp-50-20-1-1
# writing  10p200nexp-50-20-1-1
# writing  10p1000nexp-50-20-1-1
# writing  10p10sp150x300d
# writing  10p50sp150x300d
# writing  10p100sp150x300d
# writing  10p200sp150x300d
# writing  10p1000sp150x300d
# writing  10p10nexp-50-20-4-2
# writing  10p50nexp-50-20-4-2
# writing  10p100nexp-50-20-4-2
# writing  10p200nexp-50-20-4-2
# writing  10p1000nexp-50-20-4-2
